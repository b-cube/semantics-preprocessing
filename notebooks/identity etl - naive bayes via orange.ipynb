# %% [markdown]
# something to pull the root element structure (rdf:RDF or thredds:catalog or just catalog), namespaces (used or not), urls

# %%
from lxml import etree
import os
import json
import glob

files = glob.glob('../testdata/solr_20150320/clean_20150325/*.json')

parser = etree.XMLParser(
            encoding='utf-8',
            remove_blank_text=True,
            remove_comments=True,
            recover=True
        )

def get_namespaces(xml):
    if xml is None:
        return {}
    
    document_namespaces = dict(xml.xpath('/*/namespace::*'))
    if None in document_namespaces:
        document_namespaces['default'] = document_namespaces[None]
        del document_namespaces[None]

    # now run through any child namespace issues
    all_namespaces = xml.xpath('//namespace::*')
    for i, ns in enumerate(all_namespaces):
        if ns[1] in document_namespaces.values():
            continue
        new_key = ns[0] if ns[0] else 'default%s' % i
        document_namespaces[new_key] = ns[1]
    
    return document_namespaces

def prefix(tag, namespaces):
    for prefix, ns in namespaces.iteritems():
        wrapped_ns = '{%s}' % ns
        tag = tag.replace(wrapped_ns, prefix + ':')
    if '{' in tag and '}' in tag:
        return ''

    return tag
    
classes = [('arcgis','0d1d4d8f3601e2a6a7f9b1c521f62513'),
('arcgis','ad73aa64cf507d6e269f380575c61992'),
('atom','0070e906b6084ac6a20cad65a6ba4f02'),
('atom','010175111e38f436e0191ebd7203bfde'),
('atom','04f5b54d7dfc19ed7345c6bc45922559'),
('atom','05821bda0c152ef18eb5d301c88dcab8'),
('atom','069b69e3b7b52c47c817ee37c287c07b'),
('atom','082aede90d38abff694368804aa68571'),
('atom','0b5e5f418da7117f980b2041fb6faf36'),
('atom','0d2e1493cf764a27de7784d188e90461'),
('atom','25caa3c790261937820afe76ca3ff15a'),
('atom','51186f619bb1a719702403663c08d9b5'),
('atom','e097f87fefdfb86d61799efdec8411fa'),
('atom','ef20089e0b8eeba294a04b61bdbfa1a4'),
('bibxml','00287cc04528d1c41712af55da945e24'),
('bibxml','a5fd44df1041314d4350d62bba669ce6'),
('dc','01f80523dad6ff2b151e4e0afc89befb'),
('dc','09de309796f051a66238d2c6025e4ee1'),
('ddi','0013f48a191a28c9d4478a92c775bf87'),
('ddi','003672f8a350ee74d4725180750eaacb'),
('ddi','00fc5eec12a26df7c86edbee57d2cd67'),
('ddi','065e3eb776938a6da0c930c00600b26b'),
('ddi','08e6e50c2d77ee1a596694cf2946d611'),
('ddi','140837ac58c7c2934e080cda0a44f0b2'),
('ddi','ef2f944cf8b0d8f346ad8efb5bf11b25'),
('ddi','ffd65fb37800c08f6872f10773c2a922'),
('ddx','09142c4bb8d239d7806ee698b51afc41'),
('ddx','106a5788533f4de1b24c08f24364c9c8'),
('ddx','140596c0914f62c077714bf2de32aa22'),
('ddx','23a2487ef7623306e045dd81e876d428'),
('ddx','51218dd73cd3625a427ba66c5504814d'),
('ddx','f3d2f87b126fa7796d05a19e9e23ba49'),
('dif','4467b10de266dcec83475764b98bbcb2'),
('dif','adb403490e0816da68549c49a5b9d7e4'),
('fgdc','001346b24aca9c7d741c5cc0e3186681'),
('fgdc','00305fb6ea2c40eab991e028575627f8'),
('sitemap','10c739d937a82ffea86654c23e089b93'),
('sitemap','f503d3ec04f533ea905ccea9ca5f2147'),
('unidata','000cad2cd3c475b5c9b8be509d05775f'),
('unidata','004f837a1b597462fd1f5d22a7d4af03'),
('unidata','03ba79ea9b662c15e6949f380d904c28'),
('unidata','06335160f87480b7ead00960457232b1'),
('unidata','0795c384df14b580201908bc8a78218f'),
('unidata','089f36e120fe0f65b12c38c632459f78'),
('unidata','27976b01532551c952c778bfcfd007f5'),
('unidata','4e6776e2378b064ce0035ab90b43681b'),
('unidata','a6ca98411c2942fbe1ff481c32e60d14'),
('unidata','ee54deba5cfd3d3036c6b55cac2db1d4'),
('ogc','00421049376820044fbb0dba24b71289'),
('wsdl','003bdf12f8eed0dc347904138913000e'),
('wsdl','0456592b92421f017edfe6b3e106efc6'),
('wsdl','0738b36bd140d071b5933da2e67be893'),
('wsdl','25e4043a1a2ffe7be91e9bdd75d843fa'),
('xml','a957f6bff3d2618f5e5373d1aec1c33a'),
('xml','e077d2c24716268f522043b8a90088fd'),
('xsd','08f285241d804fafdaef0b564d45029e'),
('xsd','0920ea082f0ba162c8b96611368941a8'),
('xsd','23af1e10743bcd1accf5b093d3264eef'),
('xsd','e0a0771cf79c2839f8b73c42cee40afd'),
('zenodo','045736fd17e85a751deead5d64ce5d07'),
('zenodo','dbe27b2913947bd1cbe9c7aa8d93413c'),
('zenodo','04f2650568b073a21d156bcdbfd536e8'),
('zenodo','099ca182aa8db65b6133508a92168215'),
('zenodo','446f20b963e31ba01ba50b1c09640bd6'),
('zenodo','ef21db12affabfa347ec5e004232f748')]    
    
# with open('../testdata/solr_20150320/identity_inputs_as_list.csv', 'w') as f:
#     f.write('class,data\n')
    
classified = []
unclassified = []
for f in files:
    with open(f, 'r') as g:
        data = json.loads(g.read())
    
    content = data['content'].encode('unicode_escape')
    url = data['source_url']
    digest = data['digest']
    
    xml = etree.fromstring(content, parser=parser)
    if xml is None:
        continue
        
    namespaces = get_namespaces(xml)
    
    root = xml.xpath('/*')[0].tag
    prefixed_root = prefix(root, namespaces)
    
    c = [a[0] for a in classes if a[1] == digest]
    
    if c:
        classified.append(c[0] + ',' + ' '.join([url.replace(',', ';'), 
                          prefixed_root, 
                          ' '.join(namespaces.keys()),
                          ' '.join(namespaces.values())
                          ]))
    else:
        unclassified.append(',' + ' '.join([url.replace(',', ';'), 
                          prefixed_root, 
                          ' '.join(namespaces.keys()),
                          ' '.join(namespaces.values())
                          ]))

# print url, prefixed_root, namespaces
with open('../testdata/solr_20150320/urls_classified.csv', 'w') as f:
    f.write('class,data\n')
    f.write('\n'.join(classified))

with open('../testdata/solr_20150320/urls_unclassified.csv', 'w') as f:
    f.write('class,data\n')
    f.write('\n'.join(unclassified))

# %% [markdown]
# # TODO: convert these to some 'thing': 'protocol' dictionary for the trainer

# %% [markdown]
# although that really seems not good.
#
# anyway the terms are the root element tag, the namespace set and the pieces of the URL?
#
# lets start with the element tag and the namespaces
#
# 1. get a set of iso documents
