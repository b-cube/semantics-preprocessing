# %% [markdown]
# The OAI-PMH Blog (http://ekvv.uni-bielefeld.de/blog/baseoai/) has a reasonably well-structured registry of OAI-PMH servers noting things like the framework used, identifier usage, etc.
#
# This is some basic parsing and EDA on that registry to get:
#
# 1. the repository name and URL
# 2. the framework used
# 3. use of dc:identifiers
# 4. changes to the URL (at least to know)
# 5. whether it comes out of OpenDOAR
#
# I will note that this is not a great parser in a lot of ways related to inconsistent text.

# %%
import os
from lxml import etree
import json
from bs4 import BeautifulSoup
import HTMLParser
from itertools import chain

with open('oaipmh_blog_alle.atom', 'r') as f:
    text = f.read()

xml = etree.fromstring(text)

hparse = HTMLParser.HTMLParser()

# %%
# some little xml helpers
def generate_localname_xpath(tags):
    unchangeds = ['*', '..', '.', '//*']
    return '/'.join(
        ['%s*[local-name()="%s"]' % ('@' if '@' in t else '', t.replace('@', ''))
         if t not in unchangeds else t for t in tags])

def extract_attrib(elem, tags):
    e = extract_elem(elem, tags)
    return e.strip() if e else ''


def extract_attribs(elem, tags):
    e = extract_elem(elem, tags)
    return [m.strip() for m in e]


def extract_item(elem, tags):
    e = extract_elem(elem, tags)
    return e.text.strip() if e is not None and e.text else ''


def extract_items(elem, tags):
    es = extract_elems(elem, tags)
    return [e.text.strip() for e in es if e is not None and e.text]


def extract_elems(elem, tags):
    xp = generate_localname_xpath(tags)
    return elem.xpath(xp)


def extract_elem(elem, tags):
    xp = generate_localname_xpath(tags)
    return next(iter(elem.xpath(xp)), None)

# %%
# note: not dealing with namespacing at all.

entries = xml.xpath('//*/*[local-name()="entry"]')
len(entries)
# Out:
# 200

# %% [markdown]
# Let's talk about the patterns for a minute.
#
# For the titles:
#
# Many things are "{title of the service} has ...".
#
# New services are marked as "New OAI-PMH Repository: ".
#
# It's not 100% (and why it's clearly a manual blog) that the phrase before "has" is only the name of the repository. Nor is it always clear that the "migrated" posts refer to a new URL or a new framework.
#
#
# For the text content.
#
# For a new link, it's "the new basicurl is"; for a new entry, it's "the basicurl is" (however, we can get that link from the link/@rel=alternate element).
#
# The framework used can be grokked but it also changes patterns often enough.

# %%
oais = []

def parse_title(text):
    if 'has' in text:
        parts = text.strip().split('has')
        # let's not call it a triple
        return ' '.join(parts[0].strip().split()), parts[1].strip()
    elif 'New' in text and 'repository' in text.lower(): 
        return ' '.join(text.split(':')[-1].strip().split()), 'new registry'
    else:
        print '?', text
        return text.strip(), ''

def parse_link(text):
    # little soup parser just to get the basicurl
    # this should be unescaped, etc, etc
    soup = BeautifulSoup(text)
    try:
        return soup.find_all('a')[0]['href']
    except Exception as ex:
        print line
        print ex
        return ''
    
def _clean(text):
    # this is just annoying
    replaces = ['.', 'now', '<br/>', '</p>']
    for r in replaces:
        text = text.replace(r, '')
    return text
    
def parse_content(text):
    soup = BeautifulSoup(text)
    lines = hparse.unescape(soup.text).split('\n')
    
    # we can ignore some of the paragraph blocks
    # given that we want to know that it's a new link
    # and what framework it came from (or moved to)
    
    info = {
        "repo": "",
        "repo_changed": False,
        "source": "",
        "dc:identifiers": False,
        "link": ""
    }
    
    for line in lines:
        if 'repository' in line and 'uses' in line:
            # also some html junk in here
            info['repo'] = _clean(line.strip().split('uses')[-1]).strip()
        elif 'repository' in line and 'from' in line and 'to' in line:
            info['repo'] = _clean(line.strip().split('to')[-1]).strip()
            info['repo_changed'] = True
        
        if 'OpenDOAR' in line:
            info['source'] = unicode('OpenDOAR')
        
        if 'identifiers' in line:
            info['dc:identifiers'] = True
            
        if 'the new basicurl is:' in line.lower() or 'the basicurl is:' in line.lower() \
            or 'the oai-pmh basicurl is:' in line.lower() or 'the oa basicurl is:' in line.lower():
            info['link'] = parse_link(line)
            
    return info

for entry in entries:
    title = entry.xpath('./*[local-name()="title"]/text()')
    # bah. wrong link.
    # oai_link = entry.xpath('./*[local-name()="link" and @rel="alternate"]/@href')
    
    # get the content which will be escaped html
    content = entry.xpath('./*[local-name()="content"]')
    
    name, event = parse_title(title[0])
    info = parse_content(etree.tostring(content[0]))
    
    oais.append(dict(chain.from_iterable((
        {
            "name": unicode(name), 
            "event": unicode(event)
        }.items(),
        info.items()
    ))))
# Out:
# ? New OAI-PMH system: Research Index FOX of the Leuphana University Lüneburg, Germany
# ? New OA journal platform: SEDinst International Journals, The Science and Education Development Institutea
# ? New OA Journal: Otolaryngology online journal
# ? The Caltech Environmental Quality Laboratory Technical Reports have abondened their OAI-PMH interface
# ? UJDigispace of Univ. Johannesburg changed the OAI-PMH basicurl
# ? OA repository Linnaeus University Publications re-organized
# ? Brandeis University Digital Collections have moved to Brandeis Institutional Repository
# ? OAI-PMH interface available for Publications from Karolinska Institutet
# ? Norwegian Brage repositoires with improved OAI-PMH interface
# ? OACIS of Tokyo University of Marine Science and Technology (TUMSAT) is accessible via OAI-PMH
# ? Migrated repository: RiuNet with new url and new basicurl
# ? ElAr, Open Electronic Archive of Kharkov National University of Radioelectronics is accessible via OAI-PMH now
# ? Colecciones Digitales Uniminuto with OAI-PMH basicurl now
# ? National United University Institutional Repository with modified basicurl
# ? UNED Madrid with modified basicurl
# ? Theses de l'ULP, Univ Strassburg with modified basicurl
# ? National Central University Institutional Repository (NCUIR), Taiwan uses a modified basicurl
# ? Feng Chia University Repository now accessible

# %%
oais[:3]
# Out:
# [{'dc:identifiers': False,
#   'event': u'been migrated',
#   'link': 'http://edoc.bbaw.de/oai?verb=Identify',
#   'name': u'Publication Server of Berlin-Brandenburgischen Akademie der Wissenschaften, Germany',
#   'repo': u'Opus 4',
#   'repo_changed': False,
#   'source': u'OpenDOAR'},
#  {'dc:identifiers': False,
#   'event': u'new registry',
#   'link': 'http://edoc.sub.uni-hamburg.de/klimawandel/oai?verb=Identify',
#   'name': u'Dokumentenserver Klimawandel of Climate Service Center/HZG , Germany',
#   'repo': u'Opus 4',
#   'repo_changed': False,
#   'source': ''},
#  {'dc:identifiers': False,
#   'event': u'been migrated to FreiDok plus',
#   'link': 'https://www.freidok.uni-freiburg.de/oai/oai2.php?verb=Identify',
#   'name': u'The FreiDok repository',
#   'repo': u'a new platform software',
#   'repo_changed': False,
#   'source': ''}]

# %% [markdown]
# so we have a dict of stuff, let's make it pretty and countable

# %%
# in pandas
import pandas as pd

df = pd.DataFrame(oais)
df
# Out:
#     dc:identifiers                                              event  \
# 0            False                                      been migrated
# 1            False                                       new registry
# 2            False                      been migrated to FreiDok plus
# 3            False                                      been migrated
# 4            False                       changed the OAI-PMH basicurl
# 5             True                     improved the OAI-PMH interface
# 6            False  been migrated to DSpace at National Taiwan Nor...
# 7            False                       changed the OAI-PMH basicurl
# 8            False                                      been migrated
# 9            False                switched the OAI-PMH basicurl again
# 10           False                                      been migrated
# 11           False                                      been migrated
# 12           False                       changed the OAI-PMH basicurl
# 13            True                     improved the OAI-PMH interface
# 14           False                                           migrated
# 15            True                     improved the OAI-PMH interface
# 16            True                     improved the OAI-PMH interface
# 17           False                       changed the OAI-PMH basicurl
# 18           False                      changed the OAI-PMH basicurl.
# 19           False                       changed the OAI-PMH basicurl
# 20           False                       changed the OAI-PMH basicurl
# 21           False                                      been migrated
# 22            True                     improved the OAI-PMH interface
# 23           False                       changed the OAI-PMH basicurl
# 24           False                       changed the OAI-PMH basicurl
# 25           False                       changed the OAI-PMH basicurl
# 26           False                     improved the OAI-PMH interface
# 27            True                     improved the OAI-PMH interface
# 28           False                                      been migrated
# 29           False                                          migrated.
# ..             ...                                                ...
# 170          False                       changed the OAI-PMH basicurl
# 171          False                       changed the OAI-PMH basicurl
# 172          False                                       new registry
# 173          False                              switched the basicurl
# 174          False                               changed the basicurl
# 175          False                               changed the basicurl
# 176          False                                              moved
# 177          False                      modified the OAI-PMH basicurl
# 178          False
# 179          False                                       new registry
# 180          False                              switched the basicurl
# 181          False                                       new registry
# 182          False
# 183          False                                       new registry
# 184          False                                   changed its urls
# 185          False                                       new registry
# 186          False                         again changed the basicurl
# 187          False                               changed the basicurl
# 188          False
# 189          False                                       new registry
# 190          False
# 191          False                                       new registry
# 192          False
# 193          False
# 194          False
# 195          False                              modified the basicurl
# 196          False
# 197          False
# 198          False
# 199          False
#
#                                                   link  \
# 0                http://edoc.bbaw.de/oai?verb=Identify
# 1    http://edoc.sub.uni-hamburg.de/klimawandel/oai...
# 2    https://www.freidok.uni-freiburg.de/oai/oai2.p...
# 3       http://eprints.teiwm.gr/cgi/oai2?verb=Identify
# 4    http://recherche.archives.somme.fr/oai_pmh.cgi...
# 5    http://repository.unimilitar.edu.co/oai/reques...
# 6    http://dspace.lib.ntnu.edu.tw/oai/request?verb...
# 7    http://www.oceandocs.org/oai/request?verb=Iden...
# 8              http://phka.bsz-bw.de/oai?verb=Identify
# 9
# 10   https://opus4.kobv.de/opus4-euv/oai?verb=Identify
# 11   https://opus4.kobv.de/opus4-uni-passau/oai?ver...
# 12   https://vtext.valdosta.edu/oai/request?verb=Id...
# 13              http://anemi.lib.uoc.gr/?verb=Identify
# 14   https://tubdok.tub.tuhh.de/oai/request?verb=Id...
# 15             http://elocus.lib.uoc.gr/?verb=Identify
# 16    http://archie.kumc.edu/oai/request?verb=Identify
# 17   http://repository.ipu-japan.ac.jp/oai/Request?...
# 18   http://publishup.uni-potsdam.de/opus4-ubp/oai?...
# 19   http://e-archivo.uc3m.es/dspace-oai/request?ve...
# 20   https://repository.unam.na/oai/request?verb=Id...
# 21   http://repository.lasalle.edu.co/oai/request?v...
# 22   http://gru.openrepository.com/gru/oai/request?...
# 23     https://dspace.vsb.cz/oai/request?verb=Identify
# 24   https://fagarkivet.hioa.no/oai/request?verb=Id...
# 25   http://wellcomeimages.org/wellcome_oai?verb=Id...
# 26   http://e-publications.une.edu.au/fedora/oai?ve...
# 27   http://digitalcase.case.edu:9000/fedora/oai?ve...
# 28   https://tspace.library.utoronto.ca/oai/request...
# 29   http://ir.lib.hiroshima-u.ac.jp/api/oai/reques...
# ..                                                 ...
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183     http://oar.marine.ie/oai/request?verb=Identify
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
#
#                                                   name  \
# 0    Publication Server of Berlin-Brandenburgischen...
# 1    Dokumentenserver Klimawandel of Climate Servic...
# 2                               The FreiDok repository
# 3          Library of ΤΕΙ of Western Macedonia, Greece
# 4               Mémoires de la Somme Archives en ligne
# 5    Repositorio Documental UMNG of Universidad Mil...
# 6         National Taiwan Normal University Repository
# 7                                            OceanDocs
# 8    OPUS-PHKA, the Publication Server of Karlsruhe...
# 9    Massey Research Online, the institutional repo...
# 10   Publication Server of Europa-University Viadri...
# 11   Dokumentenserver der Universität Passau of Pas...
# 12   Vtext Repository of Valdosta State University, US
# 13   Anemi (Digital Library of Modern Greek Studies...
# 14   TUBdok, the open access repository of TUHH. Ge...
# 15   E-Locus, the institutional repository of the U...
# 16   Archie Digital Collections, the repository of ...
# 17   OCEAN IPU Repository of International Pacific ...
# 18   publish.UP, the publication portal of the Univ...
# 19   e-Archivo, the Institutional Repository of Car...
# 20   UNAM Scholarly Repository of University of Nam...
# 21   UNISALLE – RIUS, the research repository of Un...
# 22   Scholarly Commons, the institutional repositor...
# 23   DSpace VŠB-TUO, the repository of the Technica...
# 24   Fagarkivet HIOA, the repository of Høgskolen i...
# 25                                wellcome images, UK,
# 26   e-publications@UNE, the institutional research...
# 27   Digital Case, the repository of Case Western R...
# 28   TSpace, the research repository of University ...
# 29   HiR, Hiroshima University Institutional Reposi...
# ..                                                 ...
# 170               MSpace at the University of Manitoba
# 171         Institutional Repository @ BRAC University
# 172          eSport of German Sport University Cologne
# 173                        DSpace at University Leiden
# 174  Bayerische Staatsbibliothek München: Digitale ...
# 175  NPUE IR of National Pingtung University of Edu...
# 176           Queensland DPI&F eResearch Archive (eRA)
# 177      Malmö University Electronic Publishing (MUEP)
# 178  OAI-PMH interface available for Publications f...
# 179  OPUS - Online-Publikations-Server der Hochschu...
# 180           E-Dissertationen der Universität Hamburg
# 181  RODIN, Object Repository for Teaching and Rese...
# 182  Norwegian Brage repositoires with improved OAI...
# 183  Marine Institute Open Access Repository, Galwa...
# 184  Taiwan Theological College & Seminary Digital ...
# 185  USFSP Digital Archive (University of South Flo...
# 186  National Cheng Kung University Institutional R...
# 187     Digitum (Depósito de la Universidad de Murcia)
# 188  OACIS of Tokyo University of Marine Science an...
# 189         HilDok (University of Hildesheim, Germany)
# 190  Migrated repository: RiuNet with new url and n...
# 191  Te Tumu Eprints Repository with OAI-PMH interface
# 192  ElAr, Open Electronic Archive of Kharkov Natio...
# 193  Colecciones Digitales Uniminuto with OAI-PMH b...
# 194  National United University Institutional Repos...
# 195  OPuS-Publikationsserver, Berufsverband Informa...
# 196                 UNED Madrid with modified basicurl
# 197  Theses de l'ULP, Univ Strassburg with modified...
# 198  National Central University Institutional Repo...
# 199     Feng Chia University Repository now accessible
#
#                                                   repo repo_changed    source
# 0                                               Opus 4        False  OpenDOAR
# 1                                               Opus 4        False
# 2                              a new platform software        False
# 3                                              EPrints        False
# 4                                                             False
# 5                                               DSpace        False  OpenDOAR
# 6                                                             False  OpenDOAR
# 7                                                             False  OpenDOAR
# 8                                               Opus 4        False  OpenDOAR
# 9                                               DSpace        False  OpenDOAR
# 10                                              Opus 4        False  OpenDOAR
# 11                                              Opus 4        False  OpenDOAR
# 12                                              DSpace        False  OpenDOAR
# 13                                            Keystone        False  OpenDOAR
# 14                                              DSpace         True  OpenDOAR
# 15                                            Keystone        False  OpenDOAR
# 16                                              DSpace        False  OpenDOAR
# 17                                                            False  OpenDOAR
# 18                                               Opus4         True  OpenDOAR
# 19                                              DSpace        False  OpenDOAR
# 20                                              DSpace        False  OpenDOAR
# 21                                              DSpace        False
# 22                                                            False  OpenDOAR
# 23                                              DSpace        False  OpenDOAR
# 24                                              DSpace        False  OpenDOAR
# 25                                                            False
# 26                                              Fedora        False  OpenDOAR
# 27                                              Fedora        False  OpenDOAR
# 28                                              DSpace        False  OpenDOAR
# 29                                              DSpace        False  OpenDOAR
# ..                                                 ...          ...       ...
# 170                                                           False
# 171                                             DSpace        False
# 172                                            EPrints        False
# 173                                                           False
# 174                                                           False
# 175                                             DSpace        False
# 176                                        EPrints 313        False
# 177                                                           False
# 178                                             DSpace         True
# 179                                                           False
# 180                                                           False  OpenDOAR
# 181  DSpace and delivers currently around 4100 meta...        False
# 182                                                           False
# 183                                                           False
# 184                                             DSpace        False
# 185                                             DSpace        False
# 186                                                           False
# 187                                                           False
# 188                                                           False
# 189                                                           False
# 190                                             DSpace        False
# 191                                                           False
# 192                                                           False
# 193                                                           False
# 194                                                           False
# 195                                                           False
# 196                                                           False
# 197                                                           False
# 198                                the DSpace software        False
# 199                                                           False
#
# [200 rows x 7 columns]

# %%
df.to_csv('oaipmh_blog_alle.csv', sep='|', encoding='utf-8')

# %% [markdown]
# ### Some preliminary results
#
# (Apologies for not putting it in the pandas. Todo later with a bit of tweaking for the wonky URL extraction. take the numbers with a grain of salt re: "correct" parsing.)
#
# The feed describes 200 OAI-PMH events - new repository, changes to the access URL, etc.
#
# Rough numbers for the platforms used (half of the 200 included a recognizable value):
#
# DSpace: 56
# Eprints: 11
# Opus: 10
# Alfresco: 1
# ContentDM: 1
# DigitalCommons: 1
# Fedora: 2
# Goobi: 1
# Islandora: 1
# JaDoX: 1
# Keystone: 2
# MyCoRe: 2
# OJS: 4
# Pure: 1
#
# 79 entries were pulled from the OpenDOAR listings.
#
# I am missing half of the links.
