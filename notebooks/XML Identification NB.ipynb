# %% [markdown]
# ### Initial round of testing for Naive Bayes and XML Identification
#
# With a set of labelled responses (nb_training_201504\*.csv) and the set of all iso/ogc responses (nb_testing_201504\*.csv), we are trying to see if a naive bayes classifier can accurately identify iso or ogc or iso and ogc.
#
# Steps:
#
# from the training set:
#
# * strip out root tags
#
# * strip out namespaces
#
# * add the label from the csv
#
# from the test set:
#
# * generate a sample set (no replacement & digest not in training (my bad))
#
# * strip out root tags
#
# * strip out namespaces
#
# * predict!

# %%
from lxml import etree
import csv
import os
import json
import random

# the xml processing
parser = etree.XMLParser(
            encoding='utf-8',
            remove_blank_text=True,
            remove_comments=True,
            recover=True
        )

def get_namespaces(xml):
    if xml is None:
        return {}
    
    document_namespaces = dict(xml.xpath('/*/namespace::*'))
    if None in document_namespaces:
        document_namespaces['default'] = document_namespaces[None]
        del document_namespaces[None]

    # now run through any child namespace issues
    all_namespaces = xml.xpath('//namespace::*')
    for i, ns in enumerate(all_namespaces):
        if ns[1] in document_namespaces.values():
            continue
        new_key = ns[0] if ns[0] else 'default%s' % i
        document_namespaces[new_key] = ns[1]
    
    return document_namespaces

def prefix(tag, namespaces):
    for prefix, ns in namespaces.iteritems():
        wrapped_ns = '{%s}' % ns
        tag = tag.replace(wrapped_ns, prefix + ':')
    if '{' in tag and '}' in tag:
        return ''

    return tag

# our file location
INPUT_DIR = '../testdata/solr_20150320/clean_20150325'
# sample size
SAMPLE_SIZE = 100

training_digests = []
training_data = []
with open('../testdata/nb_training_20150405.csv', 'rb') as csvfile:
    test_reader = csv.DictReader(csvfile, fieldnames=['label', 'digest'])
    
    for row in test_reader:
        # do the things
        if not os.path.exists(os.path.join(INPUT_DIR, row['digest'] + '_cleaned.json')):
            print 'no file:', os.path.join(INPUT_DIR, row['digest'] + '_cleaned.json')
            continue
        
        with open(os.path.join(INPUT_DIR, row['digest'] + '_cleaned.json'), 'r') as f:
            data = json.loads(f.read())
        
        content = data['content'].encode('unicode_escape')
        
        try:
            xml = etree.fromstring(content, parser=parser)
        except:
            print 'bad xml', row['digest']
            continue
        
        if xml is None:
            print 'wtf xml'
            continue
        
        ns = get_namespaces(xml)
        root = xml.xpath('/*')[0].tag
        prefixed_root = prefix(root, ns)
        
        features = [prefixed_root] + list(set(ns.values()))
    
        training_digests.append(row['digest'])
        training_data += [({feature: True}, row['label']) for feature in features]
    
print len(training_data)
print training_data[:5]
# Out:
# 932
# [({'default:WMS_Capabilities': True}, 'ogc'), ({'http://www.opengis.net/wms': True}, 'ogc'), ({'http://www.w3.org/XML/1998/namespace': True}, 'ogc'), ({'http://www.w3.org/1999/xlink': True}, 'ogc'), ({'http://www.w3.org/2001/XMLSchema-instance': True}, 'ogc')]

# %%
# let's put together our test data
# where we want some sampling mechanism

test_data = {}
test_digests = []
# this time, pull the digest list without processing anything
with open('../testdata/nb_testing_20150405.csv', 'rb') as csvfile:
    test_reader = csv.DictReader(csvfile, fieldnames=['label', 'digest'])
    
    for row in test_reader:
        # do the things
        if not os.path.exists(os.path.join(INPUT_DIR, row['digest'] + '_cleaned.json')):
            print 'no file:', os.path.join(INPUT_DIR, row['digest'] + '_cleaned.json')
            continue
        
        test_digests.append((row['digest'], row['label']))

# remove any digest found in our training set
test_digests = [t for t in test_digests if t[0] not in training_digests]

sample_digests = [test_digests[t] for t in random.sample(xrange(len(test_digests)), SAMPLE_SIZE)]

# and pulling the "text" - root tags and namespaces
# note: our initial test set is only ogc and iso
for digest, label in sample_digests:
    if not os.path.exists(os.path.join(INPUT_DIR, digest + '_cleaned.json')):
        print 'no file:', os.path.join(INPUT_DIR, digest + '_cleaned.json')
        continue

    with open(os.path.join(INPUT_DIR, digest + '_cleaned.json'), 'r') as f:
        data = json.loads(f.read())

    content = data['content'].encode('unicode_escape')

    try:
        xml = etree.fromstring(content, parser=parser)
    except:
        print 'bad xml', digest
        continue

    if xml is None:
        print 'wtf xml'
        continue

    ns = get_namespaces(xml)
    root = xml.xpath('/*')[0].tag
    prefixed_root = prefix(root, ns)
    
    features = [prefixed_root] + list(set(ns.values()))
    
    test_data[digest] = [({feature:True}, label) for feature in features]

print test_data.keys()[0], test_data[test_data.keys()[0]]
# Out:
# f62ac81d9ec55eede4abec51a0a2e7d5 [({'gmi:MI_Metadata': True}, 'iso'), ({'http://www.isotc211.org/2005/gmi': True}, 'iso'), ({'http://www.opengis.net/gml/3.2': True}, 'iso'), ({'http://www.w3.org/2001/XMLSchema-instance': True}, 'iso'), ({'http://www.isotc211.org/2005/gts': True}, 'iso'), ({'http://www.isotc211.org/2005/gmx': True}, 'iso'), ({'http://www.isotc211.org/2005/gmd': True}, 'iso'), ({'http://www.isotc211.org/2005/gsr': True}, 'iso'), ({'http://www.isotc211.org/2005/gss': True}, 'iso'), ({'http://www.isotc211.org/2005/gco': True}, 'iso'), ({'http://www.w3.org/XML/1998/namespace': True}, 'iso'), ({'http://www.w3.org/1999/xlink': True}, 'iso')]

# %%
# the naive bayes
#from sklearn.naive_bayes import GaussianNB

from nltk import NaiveBayesClassifier
import nltk.classify
from collections import Counter

classifier = NaiveBayesClassifier.train(training_data)

# print classifier.show_most_informative_features(200)

for k, v in test_data.iteritems():
    items = []
    for f, l in v:
        items.append(classifier.classify(f))
    accuracy = nltk.classify.accuracy(classifier, v)
    print k, [t[1] for t in test_digests if t[0] == k] 
    print '\t', accuracy, dict(Counter(items))  # , items
# Out:
# f62ac81d9ec55eede4abec51a0a2e7d5 ['iso']
# 	1.0 {'iso': 12}
# 530802367366f7088a56f415244b1873 ['ogc']
# 	0.5 {'iso': 3, 'ogc': 3}
# cc7becfd02636988c07eb118542e3da4 ['iso']
# 	1.0 {'iso': 10}
# 547e8099083855d9367b1d60194e2885 ['ogc']
# 	0.6 {'iso': 2, 'ogc': 3}
# f4d76d2eda56e753f9e2f5bf6ed494c3 ['iso']
# 	1.0 {'iso': 12}
# 5f04d17452571df4ad4d82a40661f316 ['ogc']
# 	0.5 {'iso': 3, 'ogc': 3}
# 71ba46afae15e2b15e8db810ea311325 ['iso']
# 	1.0 {'iso': 12}
# 834734a779bfc874822e5152d95bb8f5 ['iso']
# 	1.0 {'iso': 12}
# efa09313acdac9880f0e20807e74b662 ['iso']
# 	1.0 {'iso': 12}
# 743d8d3bddbbc37596dc894f88b374c1 ['ogc']
# 	0.5 {'iso': 3, 'ogc': 3}
# 70ff9d82067751ea8e57f7e6d3090c37 ['iso']
# 	1.0 {'iso': 12}
# 432a4537313978dd7d22a7ad707d1e9a ['iso']
# 	1.0 {'iso': 12}
# 1c6b8c40972f7a94effa34d4a5178621 ['iso']
# 	1.0 {'iso': 12}
# f5417c634b19ad2fe4920dd040e5e159 ['ogc']
# 	0.5 {'iso': 3, 'ogc': 3}
# e945855423b258b4a8b7bb21170af52f ['iso']
# 	0.857142857143 {'iso': 6, 'ogc': 1}
# ...

# %% [markdown]
# The informative features:
#
# ```
# Most Informative Features
# http://www.isotc211.org/2005/gco = True              iso : ogc    =     14.0 : 1.0
# http://www.isotc211.org/2005/gmd = True              iso : ogc    =     14.0 : 1.0
# http://www.isotc211.org/2005/srv = True              iso : ogc    =      3.7 : 1.0
# http://www.opengis.net/gml = True              ogc : iso    =      3.6 : 1.0
# http://www.w3.org/2001/XMLSchema = True              iso : ogc    =      1.5 : 1.0
# http://www.w3.org/1999/xlink = True              ogc : iso    =      1.4 : 1.0
# http://www.w3.org/XML/1998/namespace = True              ogc : iso    =      1.4 : 1.0
# http://www.w3.org/2001/XMLSchema-instance = True              ogc : iso    =      1.3 : 1.0
# http://www.opengis.net/cat/csw/2.0.2 = True              iso : ogc    =      1.2 : 1.0
# http://www.isotc211.org/2005/gco = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gmd = None              ogc : iso    =      1.1 : 1.0
# http://www.opengis.net/gml/3.2 = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gts = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gmx = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gmi = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gss = None              ogc : iso    =      1.1 : 1.0
# http://www.isotc211.org/2005/gsr = None              ogc : iso    =      1.1 : 1.0
# http://www.opengis.net/wms = None              iso : ogc    =      1.1 : 1.0
# default:WMS_Capabilities = None              iso : ogc    =      1.1 : 1.0
#          gmi:MI_Metadata = None              ogc : iso    =      1.1 : 1.0
#  http://www.esri.com/wms = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/XML/1998/namespace = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/1999/xlink = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/ogc = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/gml = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/wfs = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/ows = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/2001/XMLSchema-instance = None              iso : ogc    =      1.0 : 1.0
#      WMT_MS_Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://www.isotc211.org/2005/srv = None              ogc : iso    =      1.0 : 1.0
#     wfs:WFS_Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/ows/1.1 = None              iso : ogc    =      1.0 : 1.0
#          gmd:MD_Metadata = None              ogc : iso    =      1.0 : 1.0
# default:WFS_Capabilities = None              iso : ogc    =      1.0 : 1.0
#     default:Capabilities = None              iso : ogc    =      1.0 : 1.0
#      default:MI_Metadata = None              ogc : iso    =      1.0 : 1.0
# http://www.opengis.net/wcs = None              iso : ogc    =      1.0 : 1.0
# http://inspire.ec.europa.eu/schemas/common/1.0 = None              iso : ogc    =      1.0 : 1.0
#         csw:Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/ = None              iso : ogc    =      1.0 : 1.0
# http://purl.org/dc/elements/1.1/ = None              iso : ogc    =      1.0 : 1.0
# default:WCS_Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/1999/02/22-rdf-syntax-ns# = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/wmts/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/2003/05/soap-envelope = None              iso : ogc    =      1.0 : 1.0
# urn:oasis:names:tc:ebxml-regrep:xsd:rim:3.0 = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/cat/csw/apiso/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/wcs/1.1 = None              iso : ogc    =      1.0 : 1.0
# http://www.sitemaps.org/schemas/sitemap/0.9 = None              iso : ogc    =      1.0 : 1.0
# http://a9.com/-/spec/opensearch/1.1/ = None              iso : ogc    =      1.0 : 1.0
# http://purl.org/dc/terms/ = None              iso : ogc    =      1.0 : 1.0
# http://www.w3.org/2005/Atom = None              iso : ogc    =      1.0 : 1.0
# http://inspire.ec.europa.eu/schemas/inspire_ds/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/cat/wrs/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/cat/csw/csdgm = None              iso : ogc    =      1.0 : 1.0
#        default:DS_Series = None              ogc : iso    =      1.0 : 1.0
# http://www.w3.org/2005/xpath-functions = None              ogc : iso    =      1.0 : 1.0
#      default:MD_Metadata = None              ogc : iso    =      1.0 : 1.0
# http://www.w3.org/2001/XMLSchema = None              ogc : iso    =      1.0 : 1.0
# http://www.fao.org/geonetwork = None              ogc : iso    =      1.0 : 1.0
# http://opengeo.org/#temporero = None              iso : ogc    =      1.0 : 1.0
# http://inspire.ec.europa.eu/schemas/inspire_vs/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/data/collection/nagdc = None              iso : ogc    =      1.0 : 1.0
# http://geo.prgap.org/geoserver/habitats = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/data/collection/grand-v1 = None              iso : ogc    =      1.0 : 1.0
# http://geo.prgap.org/geoserver/landcover/ = None              iso : ogc    =      1.0 : 1.0
#    wfs:FeatureCollection = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/es/esi/ = None              iso : ogc    =      1.0 : 1.0
#         http://prgap.org = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/ferman-v1 = None              iso : ogc    =      1.0 : 1.0
# http://localhost:8080/geoserver/caribbean = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/energy/ = None              iso : ogc    =      1.0 : 1.0
# http://services.nationalmap.gov/arcgis/services/WFS/geonames/MapServer/WFSServer = None              iso : ogc    =      1.0 : 1.0
# http://geo.prgap.org/atlas = None              iso : ogc    =      1.0 : 1.0
#    http://www.nature.com = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/mva/cropclimate = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/sdei/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/gpw/global.jsp = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/gateway/guides/synthetic.html = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/sos/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://localhost:6080/arcgis/services/QPF/MapServer/WFSServer = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/es/anthropogenicbiomes.html = None              iso : ogc    =      1.0 : 1.0
# http://mapserver.gis.umn.edu/mapserver = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/wdc/hazards.jsp = None              iso : ogc    =      1.0 : 1.0
#     wcs:WCS_Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/wildareas/ = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/swe/1.0 = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/usgrid/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/species/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/es/aglands.html = None              iso : ogc    =      1.0 : 1.0
# http://localhost:6080/arcgis/services/FOP/MapServer/WFSServer = None              iso : ogc    =      1.0 : 1.0
#     http://epi.yale.edu/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/icwq = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/data/collection/lulc = None              iso : ogc    =      1.0 : 1.0
# http://stategeothermaldata.org/uri-gin/aasg/xmlschema/welllog/0.8 = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/lecz/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/gpw/ = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/es/mcc.html = None              iso : ogc    =      1.0 : 1.0
#         sos:Capabilities = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/povmap = None              iso : ogc    =      1.0 : 1.0
# http://www.ciesin.columbia.edu = None              iso : ogc    =      1.0 : 1.0
# http://stategeothermaldata.org/uri-gin/aasg/xmlschema/fault/1.1 = None              iso : ogc    =      1.0 : 1.0
# http://sedac.ciesin.columbia.edu/data/collection/superfund = None              iso : ogc    =      1.0 : 1.0
# http://medford.opengeo.org = None              iso : ogc    =      1.0 : 1.0
# http://www.oostethys.org/schemas/0.1.0/oostethys = None              iso : ogc    =      1.0 : 1.0
#   http://usa.opengeo.org = None              iso : ogc    =      1.0 : 1.0
#       http://opengeo.org = None              iso : ogc    =      1.0 : 1.0
# http://geo.prgap.org/geoserver/occurrences/ = None              iso : ogc    =      1.0 : 1.0
# http://world.opengeo.org = None              iso : ogc    =      1.0 : 1.0
# http://www.opengis.net/cat/csw/2.0.2 = None              ogc : iso    =      1.0 : 1.0
#     http://saxon.sf.net/ = None              ogc : iso    =      1.0 : 1.0
# ```
