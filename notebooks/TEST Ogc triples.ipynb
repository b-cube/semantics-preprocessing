# %% [markdown]
# OGC triples for WxS GetCapabilities as Catalog Records

# %%
# %reload_ext autoreload
# %autoreload 2

import os
import json
import glob
from semproc.parser import Parser
from semproc.preprocessors.ogc_preprocessors import OgcReader
from semproc.serializers.rdfgraphs import RdfGrapher

# %%
with open('../response_examples/wms_v1.3.0.xml', 'r') as f:
    response = f.read()

# this shouldn't be necessary but cargo-culting here is fine by me.
response = response.replace('\\\n', '').replace('\r\n', '').replace('\\r', '').replace('\\n', '').replace('\n', '')
response = response.decode('utf-8', errors='replace').encode('unicode_escape') 
    
url = 'http://ferret.pmel.noaa.gov/thredds/wms/las/woa05_monthly/data_ferret.pmel.noaa.gov_thredds_dodsC_data_PMEL_WOA05nc_monthly_o0112mn1.nc.jnl'
identity = {
    "service": {
        "name": "WMS",
        "request": "GetCapabilities",
        "version": [
            "1.3.0"
        ]
    },
    "protocol": "OGC"
}

# %%
reader = OgcReader(identity, response, url, {'harvest_date': '2015-09-15T12:45:00Z'})

# %%
reader.parse()

# %%
reader.description['datasets']
# Out:
# [{'dateCreated': '2015-09-15T12:45:00Z',
#   'description': 'Dissolved Oxygen',
#   'lastUpdated': '2015-09-15T12:45:00Z',
#   'object_id': 'urn:uuid:2725de5d-42cd-4449-aade-de4ceeef8c60',
#   'relationships': [{'object_id': 'urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48',
#     'relate': 'hasMetadataRecord'}],
#   'spatial_extent': {'east': 180.0,
#    'north': 89.5,
#    'south': -89.5,
#    'west': -180.0,
#    'wkt': 'POLYGON ((-180.0 -89.5,-180.0 89.5,180.0 89.5,180.0 -89.5,-180.0 -89.5))'},
#   'temporal_extent': {},
#   'title': ['dissolved_oxygen']}]

# %%
grapher = RdfGrapher(reader.description)
grapher.serialize()
print grapher.emit_format()
# Out:
# @prefix bcube: <http://purl.org/BCube/#> .
# @prefix bibo: <http://purl.org/ontology/bibo/#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcat: <http://www.w3.org/TR/vocab-dcat/#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix esip: <http://purl.org/esip/#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://purl.org/net/provenance/ns#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/TR/vcard-rdf/#> .
# @prefix vivo: <http://vivo.ufl.edu/ontology/vivo-ufl/#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:has <urn:uuid:8330d247-aeb1-4a11-9a8b-59e48edc7bc3> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:conformsTo <urn:uuid:21379d06-8e8f-4ed8-8b34-107df85706a6>,
#         "http://schemas.opengis.net/wms/1.3.0/capabilities_1_3_0.xsd",
#         "http://www.opengis.net/wms" ;
#     owl:a dcat:CatalogRecord ;
#     foaf:primaryTopic <urn:uuid:68cd5d1b-b1b2-41db-8dbc-94f6302c4cb4> .
#
# <urn:uuid:21379d06-8e8f-4ed8-8b34-107df85706a6> bcube:hasValue "atmosphere",
#         "climate",
#         "earth science",
#         "meteorology",
#         "ocean" ;
#     dc:hasType "theme" ;
#     dc:partOf "Unknown" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:uuid:68cd5d1b-b1b2-41db-8dbc-94f6302c4cb4> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Dissolved Oxygen" ;
#     dc:spatial "POLYGON ((-180.0 -89.5,-180.0 89.5,180.0 89.5,180.0 -89.5,-180.0 -89.5))" ;
#     dct:title "dissolved_oxygen" ;
#     esip:eastBound "180.0"^^xsd:float ;
#     esip:northBound "89.5"^^xsd:float ;
#     esip:southBound "-89.5"^^xsd:float ;
#     esip:westBound "-180.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:8330d247-aeb1-4a11-9a8b-59e48edc7bc3> bcube:HTTPStatusFamilyCode 200 ;
#     bcube:HTTPStatusFamilyType "Success message" ;
#     bcube:atTime "2015-09-15T12:45:00Z" ;
#     bcube:hasConfidence "Good" ;
#     bcube:hasUrlSource "Harvested" ;
#     bcube:reasonPhrase "OK" ;
#     bcube:statusCodeValue 200 ;
#     bcube:validatedOn "2015-09-15T12:45:00Z" ;
#     owl:a bcube:Url ;
#     vcard:hasUrl "http://ferret.pmel.noaa.gov/thredds/wms/las/woa05_monthly/data_ferret.pmel.noaa.gov_thredds_dodsC_data_PMEL_WOA05nc_monthly_o0112mn1.nc.jnl" .

# %% [markdown]
# Moving on to our other WxS options, starting with WFS.

# %%
with open('../response_examples/wfs_v1_1_0.xml', 'r') as f:
    response = f.read()

# this shouldn't be necessary but cargo-culting here is fine by me.
response = response.replace('\\\n', '').replace('\r\n', '').replace('\\r', '').replace('\\n', '').replace('\n', '')
response = response.decode('utf-8', errors='replace').encode('unicode_escape') 
    
url = 'http://ferret.pmel.noaa.gov/thredds/wms/las/woa05_monthly/data_ferret.pmel.noaa.gov_thredds_dodsC_data_PMEL_WOA05nc_monthly_o0112mn1.nc.jnl'
identity = {
    "service": {
        "name": "WFS",
        "request": "GetCapabilities",
        "version": [
            "1.1.0"
        ]
    },
    "protocol": "OGC"
}

reader = OgcReader(identity, response, url, {'harvest_date': '2015-09-15T12:45:00Z'})
reader.parse()
grapher = RdfGrapher(reader.description)
grapher.serialize()
print grapher.emit_format()
# Out:
# @prefix bcube: <http://purl.org/BCube/#> .
# @prefix bibo: <http://purl.org/ontology/bibo/#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcat: <http://www.w3.org/TR/vocab-dcat/#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix esip: <http://purl.org/esip/#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://purl.org/net/provenance/ns#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/TR/vcard-rdf/#> .
# @prefix vivo: <http://vivo.ufl.edu/ontology/vivo-ufl/#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <urn:uuid:03f45186-535d-449c-992b-ec7bbb2d60ff> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Sandstone-hosted Pb-Zn" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:047a167b-8ac6-495c-b9a3-ccbf35cbfb90> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Polymetallic vein" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:067658f1-db0e-4204-a864-b02784f0af79> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Porphyry Cu" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:0b2c01f1-60f4-4c79-979b-a1ea833ae2a2> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Porphyry Cu, BC-Ak type" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:0e8cc7ec-9a27-4127-8560-605fbb25cb3c> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Mississippi Valley, Appalachian Zn" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:103fd24e-bad3-426e-999d-4418f1f37290> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Mississippi Valley, minor" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid
;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:d227cb9c-f06f-4541-a1c8-2084dd69c8b4> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Sediment-hosted Cu, Revett" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:d4791c30-c9b9-40bc-aa17-6d1f2a2ed2d9> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Basaltic Cu/Kennecott Cu" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:de2cda77-4966-4fa0-8a7a-d02217365c7b> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Alkaline Au-Te" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:de45fcf7-c256-4aae-b90b-974a44f909be> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Low-sulfide Au-quartz veins, Chugach type" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:e4acc9ae-291a-4fbe-8ab2-338993f3b935> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Polymetallic replacement" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:e806d7d9-9bf6-415d-a208-c2a5d18a10c2> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Porphyry Cu" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:f0e307ff-85fb-4ad3-91db-a58497b5d0cb> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Synorogenic-synvolcanic Ni-Cu" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:f570d021-f4bf-411b-ace4-d3e422284de1> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Massive sulfide, kuroko" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:f7f5b64b-c66e-4bb9-b1c8-4357b3d54409> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts for Sediment-hosted Cu, reduced-facies (modified)" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:f92da231-69b4-4311-8ec6-ba57df9c9c5c> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Estimates of the number and size of undiscovered mineral deposits of this type in Alaska" ;
#     dc:spatial "POLYGON ((-165 24,-165 73,-66 73,-66 24,-165 24))" ;
#     dct:title "Permissive tracts in Alaska for Sandstone hosted Pb-Zn" ;
#     esip:eastBound "-66.0"^^xsd:float ;
#     esip:northBound "73.0"^^xsd:float ;
#     esip:southBound "24.0"^^xsd:float ;
#     esip:westBound "-165.0"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:uuid:fc709b48-6dc0-4436-a253-5552c749ab53> bcube:hasValue "metallic mineral resources; natural resource assessment; gold; silver; copper; lead; zinc" ;
#     dc:hasType "theme" ;
#     dc:partOf "Unknown" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:has <urn:uuid:6907578f-a279-4e7d-81b3-9147eb67e4d4> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:conformsTo <urn:uuid:fc709b48-6dc0-4436-a253-5552c749ab53>,
#         "http://schemas.opengis.net/wfs/1.1.0/wfs.xsd",
#         "http://www.opengis.net/wfs" ;
#     owl:a dcat:CatalogRecord ;
#     foaf:primaryTopic <urn:uuid:03f45186-535d-449c-992b-ec7bbb2d60ff>,
#         <urn:uuid:047a167b-8ac6-495c-b9a3-ccbf35cbfb90>,
#         <urn:uuid:067658f1-db0e-4204-a864-b02784f0af79>,
#         <urn:uuid:0b2c01f1-60f4-4c79-979b-a1ea833ae2a2>,
#         <urn:uuid:0e8cc7ec-9a27-4127-8560-605fbb25cb3c>,
#         <urn:uuid:103fd24e-bad3-426e-999d-4418f1f37290>,
#         <urn:uuid:13a444d2-6a02-4985-ab3a-ac53af38b5f8>,
#         <urn:uuid:18bf292a-8965-4d3a-a983-54c95928148e>,
#         <urn:uuid:19c6a3e0-f188-4485-8d11-9b7c8f982ebf>,
#         <urn:uuid:1e27f73e-6fda-4649-b262-981290450d16>,
#         <urn:uuid:1f0b15f2-37f0-41f3-b5f2-39fb7df1cb7d>,
#         <urn:uuid:2034087c-9d20-480a-847e-9cbf613081e7>,
#         <urn:uuid:96b42d22-d0c5-4f3c-9f36-56cea9b33991>,
#         <urn:uuid:994d277c-0a99-4c53-8233-5b04b1f92a72>,
#         <urn:uuid:9aec436e-e570-4f12-9e47-4e4340521394>,
#         <urn:uuid:9b490720-59d9-4ba9-bf68-f42c08815f38>,
#         <urn:uuid:9b63357c-b627-47ad-af69-e76ca24a1183>,
#         <urn:uuid:9d3d8b1b-322d-4ab3-8166-4e49d2dd873e>,
#         <urn:uuid:9eb2324b-50e7-42a8-8fe9-79122bb245a6>,
#         <urn:uuid:9f294e8e-2f42-4a37-8fea-96051cae51c3>,
#         <urn:uuid:9f8b592f-f81e-4e57-b769-7a086ad6c054>,
#         <urn:uuid:a2726c42-bef8-4975-80f1-a26a2c23cc06>,
#         <urn:uuid:a5d83804-b4a5-4d87-9bdb-3df8219a8240>,
#         <urn:uuid:b589318e-de3d-4757-99fe-09e62d589b4f>,
#         <urn:uuid:b74dcd04-3d92-411a-a0b9-b2c4e8b2eb0a>,
#         <urn:uuid:c33a61d0-9e99-4ee3-8fd2-801d68562367>,
#         <urn:uuid:c65a0713-697c-4e8c-933c-77ca88a946b1>,
#         <urn:uuid:d227cb9c-f06f-4541-a1c8-2084dd69c8b4>,
#         <urn:uuid:d4791c30-c9b9-40bc-aa17-6d1f2a2ed2d9>,
#         <urn:uuid:de2cda77-4966-4fa0-8a7a-d02217365c7b>,
#         <urn:uuid:de45fcf7-c256-4aae-b90b-974a44f909be>,
#         <urn:uuid:e4acc9ae-291a-4fbe-8ab2-338993f3b935>,
#         <urn:uuid:e806d7d9-9bf6-415d-a208-c2a5d18a10c2>,
#         <urn:uuid:f0e307ff-85fb-4ad3-91db-a58497b5d0cb>,
#         <urn:uuid:f570d021-f4bf-411b-ace4-d3e422284de1>,
#         <urn:uuid:f7f5b64b-c66e-4bb9-b1c8-4357b3d54409>,
#         <urn:uuid:f92da231-69b4-4311-8ec6-ba57df9c9c5c> .

# %% [markdown]
# Once more for WCS, although it does generally have a more limited GetCapabilities.

# %%
with open('../response_examples/wcs_v1_1_2.xml', 'r') as f:
    response = f.read()

# this shouldn't be necessary but cargo-culting here is fine by me.
response = response.replace('\\\n', '').replace('\r\n', '').replace('\\r', '').replace('\\n', '').replace('\n', '')
response = response.decode('utf-8', errors='replace').encode('unicode_escape') 
    
url = 'http://ferret.pmel.noaa.gov/thredds/wms/las/woa05_monthly/data_ferret.pmel.noaa.gov_thredds_dodsC_data_PMEL_WOA05nc_monthly_o0112mn1.nc.jnl'
identity = {
    "service": {
        "name": "WCS",
        "request": "GetCapabilities",
        "version": [
            "1.1.2"
        ]
    },
    "protocol": "OGC"
}

reader = OgcReader(identity, response, url, {'harvest_date': '2015-09-15T12:45:00Z'})
reader.parse()
grapher = RdfGrapher(reader.description)
grapher.serialize()
print grapher.emit_format()
# Out:
# @prefix bcube: <http://purl.org/BCube/#> .
# @prefix bibo: <http://purl.org/ontology/bibo/#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcat: <http://www.w3.org/TR/vocab-dcat/#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix esip: <http://purl.org/esip/#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://purl.org/net/provenance/ns#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/TR/vcard-rdf/#> .
# @prefix vivo: <http://vivo.ufl.edu/ontology/vivo-ufl/#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:has <urn:uuid:81a0aa43-9f7d-40b6-8b0b-9efc3c4dadef> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:conformsTo "http://schemas.opengis.net/ows/1.1.0/owsAll.xsd",
#         "http://schemas.opengis.net/wcs/1.1/wcsGetCapabilities.xsd",
#         "http://www.opengis.net/ows/1.1/",
#         "http://www.opengis.net/wcs/1.1" ;
#     owl:a dcat:CatalogRecord ;
#     foaf:primaryTopic <urn:uuid:ab559433-1dea-4f73-8c2b-5c5714c8328c> .
#
# <urn:uuid:81a0aa43-9f7d-40b6-8b0b-9efc3c4dadef> bcube:HTTPStatusFamilyCode 200 ;
#     bcube:HTTPStatusFamilyType "Success message" ;
#     bcube:atTime "2015-09-15T12:45:00Z" ;
#     bcube:hasConfidence "Good" ;
#     bcube:hasUrlSource "Harvested" ;
#     bcube:reasonPhrase "OK" ;
#     bcube:statusCodeValue 200 ;
#     bcube:validatedOn "2015-09-15T12:45:00Z" ;
#     owl:a bcube:Url ;
#     vcard:hasUrl "http://ferret.pmel.noaa.gov/thredds/wms/las/woa05_monthly/data_ferret.pmel.noaa.gov_thredds_dodsC_data_PMEL_WOA05nc_monthly_o0112mn1.nc.jnl" .
#
# <urn:uuid:ab559433-1dea-4f73-8c2b-5c5714c8328c> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:hasMetadataRecord <urn:sha:89c0265fb336ecbb52b9997aede4c7730d61334d49a103cd66e98e48> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:description "Gridded, high resolution ocean surface vector winds and wind stresses on a global 0.25\\xb0 grid.  This is the seasonal fall average of wind speeds from 1990 to 2010. Speeds are recorded in meters per second." ;
#     dc:spatial "POLYGON ((-99.307299753899997 16.849217106099999,-99.307299753899997 31.0960075335,-79.168204535800001 31.0960075335,-79.168204535800001 16.849217106099999,-99.307299753899997 16.849217106099999))" ;
#     dct:title "Wind Speed_1" ;
#     esip:eastBound "-79.1682045358"^^xsd:float ;
#     esip:northBound "31.0960075335"^^xsd:float ;
#     esip:southBound "16.8492171061"^^xsd:float ;
#     esip:westBound "-99.3072997539"^^xsd:float ;
#     owl:a dcat:Dataset .
