# %%
# %reload_ext autoreload
# %autoreload 2

import os
import json
import glob
from semproc.parser import Parser
from semproc.preprocessors.iso_preprocessors import IsoReader, MxParser
from semproc.serializers.rdfgraphs import RdfGrapher

# %%
with open('xmls/proto_iso_bluehub.xml', 'r') as f:
    response = f.read()

# this shouldn't be necessary but cargo-culting here is fine by me.
response = response.replace('\\\n', '').replace('\r\n', '').replace('\\r', '').replace('\\n', '').replace('\n', '')
response = response.decode('utf-8', errors='replace').encode('unicode_escape') 
    
url = 'https://bluehub.jrc.ec.europa.eu/erddap/metadata/iso/xml/noaa_pfeg_d543_8870_bc7f_iso.xml'
identity = {
    "protocol": "ISO", 
     "metadata": {
    "version": ["ISO 19115-2:2009(E)"], 
    "name": "19115"}
}

# %%
reader = IsoReader(identity, response, url, {'harvest_date': '2015-09-15T12:45:00Z'})

# %%
reader.description
# Out:
# {'catalog_record': {'conformsTo': ['http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd'],
#   'dateCreated': '2015-09-15T12:45:00Z',
#   'lastUpdated': '2015-09-15T12:45:00Z',
#   'object_id': 'urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228',
#   'relationships': [{'object_id': 'urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487',
#     'relate': 'primaryTopic'}],
#   'urls': [{'HTTPStatusFamilyCode': 200,
#     'HTTPStatusFamilyType': 'Success message',
#     'atTime': '2015-09-15T12:45:00Z',
#     'hasConfidence': 'Good',
#     'hasUrl': 'https://bluehub.jrc.ec.europa.eu/erddap/metadata/iso/xml/noaa_pfeg_d543_8870_bc7f_iso.xml',
#     'hasUrlSource': 'Harvested',
#     'object_id': 'urn:uuid:e41716c3-bb1e-406a-ab99-7976c3e33b40',
#     'reasonPhrase': 'OK',
#     'statusCodeValue': 200,
#     'validatedOn': '2015-09-15T12:45:00Z'}]},
#  'datasets': [{'abstract': "Level-3 Standard Mapped Image (SMI), Global, 4km, Diffuse Attenuation Coefficient K490, Daily composite data from the Visible and Infrared Imager/Radiometer Suite (VIIRS). VIIRS is a multi-disciplinary instrument that flies on the Suomi-NPP (National Polar-orbiting Partnership) satellite.  Suomi-NPP is the initial spacecraft in the JPSS (Joint Polar Satellite Systems) series of spacecraft. JPSS is our Nation's next generation polar-orbiting operational environmental satellite system. JPSS is a collaborative program between NOAA and its acquisition agent NASA. VIIRS is the successor to MODIS for Earth science data product generation. (This version of the VH data was first released in December 2014.)",
#    'dateCreated': '2015-09-15T12:45:00Z',
#    'identifier': 'erdVH2k4901day',
#    'lastUpdated': '2015-09-15T12:45:00Z',
#    'object_id': 'urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487',
#    'relationships': [{'object_id': 'urn:uuid:4f88cdcc-ea98-4887-a667-786ac9ed07e5',
#      'relate': 'conformsTo'},
#     {'object_id': 'urn:uuid:4ed6f4f5-126c-4741-9f9e-5bc8f7d3d5fc',
#      'relate': 'conformsTo'},
#     {'object_id': 'urn:uuid:5618cb23-f63f-4f83-b018-f95fdc2b2574',
#      'relate': 'conformsTo'},
#     {'object_id': 'urn:uuid:69c0d4f6-adc2-4e86-b00e-3389dc481929',
#      'relate': 'conformsTo'},
#     {'object_id': 'urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228',
#      'relate': 'hasMetadataRecord'},
#     {'object_id': 'urn:uuid:8bc95fcb-1ca9-4504-9563-0ee31462c876',
#      'relate': 'relation'},
#     {'object_id': 'urn:uuid:31e4038b-62b2-4226-a256-c26b1276208b',
#      'relate': 'relation'}],
#    'spatial_extent': {'east': 179.9792,
#     'north': 89.97916,
#     'south': -89.97918,
#     'west': -179.9792,
#     'wkt': 'POLYGON ((-179.9792 -89.97918,-179.9792 89.97916,179.9792 89.97916,179.9792 -89.97918,-179.9792 -89.97918))'},
#    'temporal_extent': {'endDate': '2015-09-12T12:00:00+00:00',
#     'startDate': '2012-01-02T12:00:00+00:00'},
#    'title': 'VIIRSN, Suomi-NPP, Level-3 SMI, Global, 4km, K490, Daily',
#    'urls': [{'HTTPStatusFamilyCode': 200,
#      'HTTPStatusFamilyType': 'Success message',
#      'atTime': '2015-09-15T12:45:00Z',
#      'hasConfidence': 'Good',
#      'hasUrl': 'https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.html',
#      'hasUrlSource': 'Harvested',
#      'object_id': 'urn:uuid:8bc95fcb-1ca9-4504-9563-0ee31462c876',
#      'reasonPhrase': 'OK',
#      'statusCodeValue': 200,
#      'validatedOn': '2015-09-15T12:45:00Z'},
#     {'HTTPStatusFamilyCode': 200,
#      'HTTPStatusFamilyType': 'Success message',
#      'atTime': '2015-09-15T12:45:00Z',
#      'hasConfidence': 'Good',
#      'hasUrl': 'https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.graph',
#      'hasUrlSource': 'Harvested',
#      'object_id': 'urn:uuid:31e4038b-62b2-4226-a256-c26b1276208b',
#      'reasonPhrase': 'OK',
#      'statusCodeValue': 200,
#      'validatedOn': '2015-09-15T12:45:00Z'}]}],
#  'keywords': [{'object_id': 'urn:uuid:4f88cdcc-ea98-4887-a667-786ac9ed07e5',
#    'terms': ['4km',
#     'attentuation',
#     'coefficient',
#     'composite',
#     'daily',
#     'diffuse',
#     'diffuse attenuation coefficient',
#     'gsfc',
#     'image',
#     'joint',
#     'jpss',
#     'k490',
#     'level',
#     'level-3',
#     'mapped',
#     'mean',
#     'nasa',
#     'noaa',
#     'npoess',
#     'npp',
#     'obpg',
#     'ocean',
#     'ocean color',
#     'oceans',
#     'optical',
#     'orbiting',
#     'polar',
#     'properties',
#     'satellite',
#     'sea',
#     'seawater',
#     'smi',
#     'standard',
#     'suomi',
#     'viirs',
#     'viirsn',
#     'water'],
#    'type': 'theme'},
#   {'object_id': 'urn:uuid:4ed6f4f5-126c-4741-9f9e-5bc8f7d3d5fc',
#    'terms': ['Ocean Biology Processing Group (NASA/GSFC/OBPG)'],
#    'type': 'project'},
#   {'object_id': 'urn:uuid:5618cb23-f63f-4f83-b018-f95fdc2b2574',
#    'terms': ['time',
#     'latitude',
#     'longitude',
#     'diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water'],
#    'thesaurus': 'CF Standard Name Table v29',
#    'type': 'theme'},
#   {'object_id': 'urn:uuid:69c0d4f6-adc2-4e86-b00e-3389dc481929',
#    'terms': ['geoscientificInformation'],
#    'thesaurus': 'IsoTopicCategories'}]}

# %%
reader.description['datasets']
# Out:
# [{'abstract': "Level-3 Standard Mapped Image (SMI), Global, 4km, Diffuse Attenuation Coefficient K490, Daily composite data from the Visible and Infrared Imager/Radiometer Suite (VIIRS). VIIRS is a multi-disciplinary instrument that flies on the Suomi-NPP (National Polar-orbiting Partnership) satellite.  Suomi-NPP is the initial spacecraft in the JPSS (Joint Polar Satellite Systems) series of spacecraft. JPSS is our Nation's next generation polar-orbiting operational environmental satellite system. JPSS is a collaborative program between NOAA and its acquisition agent NASA. VIIRS is the successor to MODIS for Earth science data product generation. (This version of the VH data was first released in December 2014.)",
#   'dateCreated': '2015-09-15T12:45:00Z',
#   'identifier': 'erdVH2k4901day',
#   'lastUpdated': '2015-09-15T12:45:00Z',
#   'object_id': 'urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487',
#   'relationships': [{'object_id': 'urn:uuid:e24f68da-752b-4b02-a0ec-b8cc9b73d400',
#     'relate': 'conformsTo'},
#    {'object_id': 'urn:uuid:a1b9910f-211f-4c65-955e-a78cab527bac',
#     'relate': 'conformsTo'},
#    {'object_id': 'urn:uuid:1f8166ef-b116-48aa-a210-29b9e6c6d242',
#     'relate': 'conformsTo'},
#    {'object_id': 'urn:uuid:25cf99ca-6d5c-4113-bc20-0b62cd0f6da5',
#     'relate': 'conformsTo'},
#    {'object_id': 'urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228',
#     'relate': 'hasMetadataRecord'},
#    {'object_id': 'urn:sha:4eaf6d197e57441768eda082ae24f20587d4c277e0e81011b661089e',
#     'relate': 'relation'},
#    {'object_id': 'urn:sha:afc1dbffb4e9e210a7dbf86e0f728a4e14ddb436462026570cb68f44',
#     'relate': 'relation'}],
#   'spatial_extent': {'east': 179.9792,
#    'north': 89.97916,
#    'south': -89.97918,
#    'west': -179.9792,
#    'wkt': 'POLYGON ((-179.9792 -89.97918,-179.9792 89.97916,179.9792 89.97916,179.9792 -89.97918,-179.9792 -89.97918))'},
#   'temporal_extent': {'endDate': '2015-09-12T12:00:00+00:00',
#    'startDate': '2012-01-02T12:00:00+00:00'},
#   'title': 'VIIRSN, Suomi-NPP, Level-3 SMI, Global, 4km, K490, Daily',
#   'urls': [{'format': 'OPeNDAP DAP/2.0',
#     'object_id': 'urn:sha:4eaf6d197e57441768eda082ae24f20587d4c277e0e81011b661089e',
#     'url': 'https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.html'},
#    {'format': 'OPeNDAP DAP/2.0',
#     'object_id': 'urn:sha:afc1dbffb4e9e210a7dbf86e0f728a4e14ddb436462026570cb68f44',
#     'url': 'https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.graph'}]}]

# %%
reader.description['catalog_record']
# Out:
# {'conformsTo': 'http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'dateCreated': '2015-09-15T12:45:00Z',
#  'lastUpdated': '2015-09-15T12:45:00Z',
#  'object_id': 'urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228',
#  'relationships': [{'object_id': 'urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487',
#    'relate': 'primaryTopic'}],
#  'urls': [{'HTTPStatusFamilyCode': 200,
#    'HTTPStatusFamilyType': 'Success message',
#    'atTime': '2015-09-15T12:45:00Z',
#    'hasConfidence': 'Good',
#    'hasUrl': 'https://bluehub.jrc.ec.europa.eu/erddap/metadata/iso/xml/noaa_pfeg_d543_8870_bc7f_iso.xml',
#    'hasUrlSource': 'Harvested',
#    'object_id': 'urn:uuid:771b7b08-6f67-42b6-8f89-56cc5aab78fa',
#    'reasonPhrase': 'OK',
#    'statusCodeValue': 200,
#    'validatedOn': '2015-09-15T12:45:00Z'}]}

# %%
# and the turtle?
grapher = RdfGrapher(reader.description)
grapher.serialize()

# %%
print grapher.emit_format()
# Out:
# @prefix bcube: <http://purl.org/BCube/#> .
# @prefix bibo: <http://purl.org/ontology/bibo/#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dcat: <http://www.w3.org/TR/vocab-dcat/#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix esip: <http://purl.org/esip/#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix prov: <http://purl.org/net/provenance/ns#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/TR/vcard-rdf/#> .
# @prefix vivo: <http://vivo.ufl.edu/ontology/vivo-ufl/#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:has <urn:uuid:736203f5-6359-49c8-ad78-16f5f6a2abb7>,
#         <urn:uuid:a2e06694-aa9e-43ec-bf51-3d66e3c4ffb8> ;
#     bcube:hasMetadataRecord <urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:conformsTo <urn:uuid:37cbc6ab-8851-4e3a-bb4f-081c72028471>,
#         <urn:uuid:3f3c2aa7-ee86-49a4-961c-54d1d101f1e7>,
#         <urn:uuid:8b8ec358-3306-48f2-91f7-1802e60ef8d5>,
#         <urn:uuid:b7981f45-b910-4857-a858-bdb8b351f13b> ;
#     dc:description "Level-3 Standard Mapped Image (SMI), Global, 4km, Diffuse Attenuation Coefficient K490, Daily composite data from the Visible and Infrared Imager/Radiometer Suite (VIIRS). VIIRS is a multi-disciplinary instrument that flies on the Suomi-NPP (National Polar-orbiting Partnership) satellite.  Suomi-NPP is the initial spacecraft in the JPSS (Joint Polar Satellite Systems) series of spacecraft. JPSS is our Nation's next generation polar-orbiting operational environmental satellite system. JPSS is a collaborative program between NOAA and its acquisition agent NASA. VIIRS is the successor to MODIS for Earth science data product generation. (This version of the VH data was first released in December 2014.)" ;
#     dc:relation <urn:uuid:736203f5-6359-49c8-ad78-16f5f6a2abb7>,
#         <urn:uuid:a2e06694-aa9e-43ec-bf51-3d66e3c4ffb8> ;
#     dc:spatial "POLYGON ((-179.9792 -89.97918,-179.9792 89.97916,179.9792 89.97916,179.9792 -89.97918,-179.9792 -89.97918))" ;
#     dct:identifier "erdVH2k4901day" ;
#     dct:title "VIIRSN, Suomi-NPP, Level-3 SMI, Global, 4km, K490, Daily" ;
#     esip:eastBound "179.9792"^^xsd:float ;
#     esip:endDate "2015-09-12"^^xsd:date ;
#     esip:northBound "89.97916"^^xsd:float ;
#     esip:southBound "-89.97918"^^xsd:float ;
#     esip:startDate "2012-01-02"^^xsd:date ;
#     esip:westBound "-179.9792"^^xsd:float ;
#     owl:a dcat:Dataset .
#
# <urn:sha:c2fb667c42f9774d79c895a499f319fe5795f4b3c157cc4d2cd01228> bcube:dateCreated "2015-09-15T12:45:00Z" ;
#     bcube:has <urn:uuid:b6ac8c8e-b146-4dd4-bb26-b7c378083201> ;
#     bcube:lastUpdated "2015-09-15T12:45:00Z" ;
#     dc:conformsTo "http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd" ;
#     owl:a dcat:CatalogRecord ;
#     foaf:primaryTopic <urn:sha:3a5b1e07fa71be8320545bc0e4a277259d5794e020cd6ceb5c8bd487> .
#
# <urn:uuid:37cbc6ab-8851-4e3a-bb4f-081c72028471> bcube:hasValue "diffuse_attenuation_coefficient_of_downwelling_radiative_flux_in_sea_water",
#         "latitude",
#         "longitude",
#         "time" ;
#     dc:hasType "theme" ;
#     dc:partOf "CF Standard Name Table v29" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:uuid:3f3c2aa7-ee86-49a4-961c-54d1d101f1e7> bcube:hasValue "Ocean Biology Processing Group (NASA/GSFC/OBPG)" ;
#     dc:hasType "project" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:uuid:8b8ec358-3306-48f2-91f7-1802e60ef8d5> bcube:hasValue "geoscientificInformation" ;
#     dc:partOf "IsoTopicCategories" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:uuid:b6ac8c8e-b146-4dd4-bb26-b7c378083201> bcube:HTTPStatusFamilyCode 200 ;
#     bcube:HTTPStatusFamilyType "Success message" ;
#     bcube:atTime "2015-09-15T12:45:00Z" ;
#     bcube:hasConfidence "Good" ;
#     bcube:hasUrlSource "Harvested" ;
#     bcube:reasonPhrase "OK" ;
#     bcube:statusCodeValue 200 ;
#     bcube:validatedOn "2015-09-15T12:45:00Z" ;
#     owl:a bcube:Url ;
#     vcard:hasUrl "https://bluehub.jrc.ec.europa.eu/erddap/metadata/iso/xml/noaa_pfeg_d543_8870_bc7f_iso.xml" .
#
# <urn:uuid:b7981f45-b910-4857-a858-bdb8b351f13b> bcube:hasValue "4km",
#         "attentuation",
#         "coefficient",
#         "composite",
#         "daily",
#         "diffuse",
#         "diffuse attenuation coefficient",
#         "gsfc",
#         "image",
#         "joint",
#         "jpss",
#         "k490",
#         "level",
#         "level-3",
#         "mapped",
#         "mean",
#         "nasa",
#         "noaa",
#         "npoess",
#         "npp",
#         "obpg",
#         "ocean",
#         "ocean color",
#         "oceans",
#         "optical",
#         "orbiting",
#         "polar",
#         "properties",
#         "satellite",
#         "sea",
#         "seawater",
#         "smi",
#         "standard",
#         "suomi",
#         "viirs",
#         "viirsn",
#         "water" ;
#     dc:hasType "theme" ;
#     owl:a bcube:thesaurusSubset .
#
# <urn:uuid:736203f5-6359-49c8-ad78-16f5f6a2abb7> bcube:HTTPStatusFamilyCode 200 ;
#     bcube:HTTPStatusFamilyType "Success message" ;
#     bcube:atTime "2015-09-15T12:45:00Z" ;
#     bcube:hasConfidence "Good" ;
#     bcube:hasUrlSource "Harvested" ;
#     bcube:reasonPhrase "OK" ;
#     bcube:statusCodeValue 200 ;
#     bcube:validatedOn "2015-09-15T12:45:00Z" ;
#     owl:a bcube:Url ;
#     vcard:hasUrl "https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.html" .
#
# <urn:uuid:a2e06694-aa9e-43ec-bf51-3d66e3c4ffb8> bcube:HTTPStatusFamilyCode 200 ;
#     bcube:HTTPStatusFamilyType "Success message" ;
#     bcube:atTime "2015-09-15T12:45:00Z" ;
#     bcube:hasConfidence "Good" ;
#     bcube:hasUrlSource "Harvested" ;
#     bcube:reasonPhrase "OK" ;
#     bcube:statusCodeValue 200 ;
#     bcube:validatedOn "2015-09-15T12:45:00Z" ;
#     owl:a bcube:Url ;
#     vcard:hasUrl "https://bluehub.jrc.ec.europa.eu/erddap/griddap/erdVH2k4901day.graph" .
