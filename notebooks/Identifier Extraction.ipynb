# %% [markdown]
# from urls and/or xml text/attributes, can we extract urns? uuids? guids? dois? other ids.
#
# starting from a url:
#
# 1. parse url
# 2. parse route
# 3. parse query params (un-urlencode)
# 4. check route parts
#
#
# starting with xml:
#
# 1. parse xml
# 2. run the xpath ruleset
# 3. test xpath results if results
# 4. extract all other text
# 5. check text

# %%
import json
import glob
from lxml import etree
import re
import os

# tuple = type, sample string
url_sampleset = [
('uuid', 'https://data.noaa.gov/harvest/object/b1b6e62a-cc9b-4cf5-89e5-d280e854eb1c'),
('uuid', 'https://data.noaa.gov/harvest/object/2ee5666a-2f9e-4e69-997f-474737fcce71/original'),
('urn', 'https://openknowledge.worldbank.org/oai/request?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:openknowledge.worldbank.org:10986/18612'),
('other', 'http://www.ngdc.noaa.gov/metadata/published/NOAA/NESDIS/NGDC/MGG/NOS/H10001-H12000/iso/xml/H10193.xml'),
('other', 'https://www.sciencebase.gov/catalog/item/51fc076be4b04b00e3d891e5?format=atom'),
('other', 'http://acdisc.gsfc.nasa.gov/opendap/HDF-EOS5/Aura_OMI_Level3/OMSO2e.003/2011/OMI-Aura_L3-OMSO2e_2011m0104_v003-2012m0409t151714.he5.ddx'),
('uuid', 'https://www.ngdc.noaa.gov/geoportal/rest/document?id=%7B6FCC9928-1352-44F3-9D7B-BBDC9AF15E9A%7D'),
('uuid', 'http://gstore.unm.edu/apps/rgis/datasets/35946660-26d0-4d05-955f-8af7ced2b0c1/metadata/FGDC-STD-001-1998.xml'),
('other', 'http://e4ftl01.cr.usgs.gov/MOLT/MOD14.005/2000.04.28/MOD14.A2000119.2335.005.2006261045911.hdf.xml'),
('uuid', 'http://portal.oceannet.org/search/full/catalogue/dassh.ac.uk__MEDIN_2.3__CEFAS1abbc9be-1014-45ac-a281-808310790c31.xml/DIF_9.4'),
('other', 'http://earth.eo.esa.int/ml3/n412/2005/L3_ENV_MER_N412_m__20050201_GLOB_SI_ESA_9277x9277_-90+90+-180+180_0000.xml'),
('other', 'http://www.aauw-ca.org/blog/rss.cfm?mode=full&mode2=cat&catid=9D122695-1617-7A4B-92209B7B1C4B6D75'),
('doi', 'http://data.datacite.org/10.14457/KU.THE.2006.802'),
('doi', 'http://dx.doi.org/10.4224/20386605'),
('doi', 'http://link.springer.com/referenceworkentry/10.1007%2F1-4020-3880-1_85'),
('urn', 'http://epsg-registry.org/export.htm?wkt=urn:ogc:def:crs:EPSG::4979'),
]

# %%
import urllib
import urlparse
from itertools import chain

def unquote(url):
    return urllib.unquote(url)

def return_path(url, do_split=False):
    url = unquote(url)
    if do_split:
        return urlparse.urlparse(url).path.split('/')
    return urlparse.urlparse(url).path

def return_parameter_values(url, do_split=False):
    url = unquote(url)
    parse = urlparse.urlparse(url)
    if do_split:
        qp = urlparse.parse_qs(parse.query)
        return list(chain.from_iterable(qp.values()))
    return parse.query
    
def match(s, p):
    m = re.search(p, s)
    return m.group(0) if m else ''

# %%
# extract urn patterns

# standalone
urn_pattern = re.compile(ur"^urn:[a-z0-9][a-z0-9-]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+$", re.IGNORECASE)
# in text with punctuation
urn_pattern2 = re.compile(ur"\burn:[a-z0-9][a-z0-9-]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]*[a-z0-9+=@$/]", re.IGNORECASE)
# in text
urn_pattern3 = re.compile(ur"\burn:[a-z0-9][a-z0-9-]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+", re.IGNORECASE)

# %%
# extract uuid pattern

uuid_pattern = re.compile(ur'(\w{8}(-\w{4}){3}-\w{12}?)', re.IGNORECASE)

uuid_pattern2 = re.compile(ur'([a-f\d]{8}(-[a-f\d]{4}){3}-[a-f\d]{12}?)', re.IGNORECASE)

# %%
# extract doi

doi_pattern = re.compile(ur"\b(10[.][0-9]{4,}(?:[.][0-9]+)*/(?:(?![\"&\\'])\\S)+)\b", re.IGNORECASE)

# %%
# use these patterns (so far)
pattern_set = [
('uuid', re.compile(ur'([a-f\d]{8}(-[a-f\d]{4}){3}-[a-f\d]{12}?)', re.IGNORECASE)),
('urn', re.compile(ur"\burn:[a-z0-9][a-z0-9-]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+", re.IGNORECASE)),
('doi', re.compile(ur"(10[.][0-9]{4,}(?:[/][0-9]+)*/(?:(?![\"&\\'])\S)+)", re.IGNORECASE)),
('urn', re.compile(ur"(oai:[a-z0-9.][a-z0-9-.]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+)", re.IGNORECASE))
]

# %%
# let's make a ruleset based on identified patterns:
# http://philarcher.org/diary/2013/uripersistence/

# %%
# run the checks

for kind, url in url_sampleset:
    path = return_path(url)
    query = return_parameter_values(url)
    for pttn_type, pattern in pattern_set:
        m = match(path, pattern)
        if m:
            print 'found URL match: {0}, {1}'.format(m, path)
            print '\tExpected {0}? {1}'.format(kind, kind==pttn_type)
            break
        
        m = match(query, pattern)
        if m:
            print 'found QUERY match: {0}, {1}'.format(m, query)
            print '\tExpected {0}? {1}'.format(kind, kind==pttn_type)
            break
# Out:
# found URL match: b1b6e62a-cc9b-4cf5-89e5-d280e854eb1c, /harvest/object/b1b6e62a-cc9b-4cf5-89e5-d280e854eb1c
# 	Expected uuid? True
# found URL match: 2ee5666a-2f9e-4e69-997f-474737fcce71, /harvest/object/2ee5666a-2f9e-4e69-997f-474737fcce71/original
# 	Expected uuid? True
# found QUERY match: oai:openknowledge.worldbank.org:10986/18612, verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:openknowledge.worldbank.org:10986/18612
# 	Expected urn? True
# found QUERY match: 6FCC9928-1352-44F3-9D7B-BBDC9AF15E9A, id={6FCC9928-1352-44F3-9D7B-BBDC9AF15E9A}
# 	Expected uuid? True
# found URL match: 35946660-26d0-4d05-955f-8af7ced2b0c1, /apps/rgis/datasets/35946660-26d0-4d05-955f-8af7ced2b0c1/metadata/FGDC-STD-001-1998.xml
# 	Expected uuid? True
# found URL match: 1abbc9be-1014-45ac-a281-808310790c31, /search/full/catalogue/dassh.ac.uk__MEDIN_2.3__CEFAS1abbc9be-1014-45ac-a281-808310790c31.xml/DIF_9.4
# 	Expected uuid? True
# found URL match: 10.14457/KU.THE.2006.802, /10.14457/KU.THE.2006.802
# 	Expected doi? True
# found URL match: 10.4224/20386605, /10.4224/20386605
# 	Expected doi? True
# found URL match: 10.1007/1-4020-3880-1_85, /referenceworkentry/10.1007/1-4020-3880-1_85
# 	Expected doi? True
# found QUERY match: urn:ogc:def:crs:EPSG::4979, wkt=urn:ogc:def:crs:EPSG::4979
# 	Expected urn? True

# %% [markdown]
# notes:
#
# urn regex(es) unlikely to be very generalized right now.
#
# ugh. text. and rss. and encoded html in the rss with the identifiers.

# %% [markdown]
# building the test set. get the responses for the test urls (find identifer from url in response?)
#
# go get our known similarity (ie duplicates as different representations) set and try on those responses.

# %%
import glob
import json
import re
from lxml import etree
from bs4 import BeautifulSoup
from datetime import datetime

import logging
reload(logging)

logger = logging.getLogger(__name__)
handler = logging.FileHandler(filename="identifier_extraction_%s.log" % datetime.now().strftime('%Y%m%d-%H%M'), mode="a", encoding="UTF-8")
logger.addHandler(handler)
logger.setLevel(logging.DEBUG)

# the array of any identifiers found in a url
# as (source url, identifier)
_found_identifiers = []

def un_htmlify(text):
    # for cdata wrapped things? this is unpleasant
    # but we want identifiers in the rss/atom element
    # wrapped in cdata as encoded html
    
    def _handle_bad_html(s):
        pttn = re.compile('<|>')
        return pttn.sub(' ', s)
    
    soup = BeautifulSoup(text.strip())
    
    # get all of the text and any a/@href values
    texts = [_handle_bad_html(t) for t in soup.find_all(text=True)] + \
            [unquote(a['href']) for a in soup.find_all('a') if 'href' in a.attrs]
        
    try:
        all_text = ' '.join(texts)
    except:
        raise
    return all_text

class Parser():
    def __init__(self, text):
        self.text = text
        self.parser = etree.XMLParser(
            remove_blank_text=True, 
            remove_comments=True, 
            recover=True,
            remove_pis=True
        )
        self._parse()
        
    def _parse(self):
        try:
            self.xml = etree.fromstring(text, parser=self.parser)
        except:
            raise
    
    def strip_text(self):
        # pull any text() and attribute. again.
        # bag of words BUT we care about where in
        # the tree it was found (just for thinking)
        # except do not care about namespace prefixed
        # why am i not stripping out the prefixes? no idea.
        # just don't want to install pparse/saxonb really
        
        def _extract_tag(t):
            if not t:
                return
            return t.split('}')[-1]
            
        def _taggify(e):
            tags = [e.tag] + [m.tag for m in e.iterancestors()]
            tags.reverse()
            
            try:
                return [_extract_tag(t) for t in tags]
            except Exception as ex:
                print tags
                print ex
        
        # to exclude based on the tags *only*
        exclude_pttns = ['schemaLocation']
        
        blobs = []
        for elem in self.xml.iter():
            t = elem.text.strip() if elem.text else ''
            tags = _taggify(elem)
            
            if [e for e in exclude_pttns if e in tags]:
                continue
            
            if t:
                blobs.append(('/'.join(tags), t))
            
            for k, v in elem.attrib.iteritems():
                if v.strip():
                    blobs.append(('/'.join(tags + ['@' + _extract_tag(k)]), v.strip()))
        
        return blobs
            
def process_text(text):
    # check for html, get that as a bag of space-delimited words
    # run some regex for identifiers  
    if (text.startswith('<') and text.endswith('>')) or ('<' in text or '>' in text):
        try:
            text = un_htmlify(text)
        except:
            raise
    
    # look for *any* identifiers
    for match_tuple in match_identifier_patterns(text):
        yield match_tuple

def match_identifier_patterns(s):
    space_pttn = re.compile(' ')
    exclude_pttns = [':ogc:', ':epsg:', '.xsd', 'codelist', 'rolecode', '.xsl']
    
    for pttn_type, pattern in pattern_set:
        m = match(s, pattern)
        if m and not any(e in m.lower() for e in exclude_pttns):
            if pttn_type == 'url' and space_pttn.subn('', m)[1] > 0:
                m = m.split(' ')[0]
            
            # this is stupid. i am tired. so pointless.
            try:
                log_m = m.decode('utf-8', errors='ignore')
            except:
                print 'UNICODE fail: ', m
                log_m = 'CHECK Source - unicode issues'
            logger.debug(u'MATCH_PATTERNS: {0} is a {1} from ({2})'.format(log_m, pttn_type, s))
            
            2


def match_identifier_rules(xml):
    def _get_text(e):
        if isinstance(e, str):
            return e
        try:
            return e.text
        except Exception as ex:
            # print ex
            return ''
    def _build_xpath(rule):
        return '//' + '/'.join(['%s*[local-name()="%s"]' % ('@' if '@' in r else '', r) 
                               if r not in ['*', '..', '.'] else r for r in rule.split('/')])

    for pttn_type, rule in rule_set:
        xp = _build_xpath(rule)
        results = xml.xpath(xp)
        results = results if isinstance(results, list) else [results]
        
        for r in results:
            t = _get_text(r)
            if t is None:
                continue
            
            # this is stupid. i am tired. so pointless.
            try:
                log_t = t.decode('utf-8', errors='ignore')
            except:
                print 'UNICODE fail: ', t
                log_t = 'CHECK Source - unicode issues'
            logger.debug(u'MATCH_RULES: {0} is a {1} from (the XML)'.format(log_t, pttn_type))
            
            # run the regex pass (so URL -> UUID, etc)
            for match_tuple in match_identifier_patterns(t):
                yield match_tuple

# %%
from simhash import Simhash, SimhashIndex
import hashlib

def compare(simhash_to_match):
    pass

def generate_sha(s):
    return hashlib.sha224(s).hexdigest()

# %%
# i think we'll keep these as some general xpaths without! the
# local-name/namespacing and add that in method for readability
# and assume we're looking from root (so always '//*.....')
rule_set = [
    ('uri', 'fileIdentifier/CharacterString'),  # ISO
    ('uri', 'identifier/*/code/CharacterString'),
    ('uri', 'dataSetURI/CharacterString'),
    ('uri', 'parentIdentifier/CharacterString'),
    ('uri', 'Entry_ID'),  # DIF
    ('uri', 'dc/identifier'),  # DC
    ('basic', 'Layer/Name'),  # WMS
    ('basic', 'dataset/@ID'),  # THREDDS
    ('uri', '@URI'),  ## ddi
    ('uri', '@IDNo')  ## ddi
]

# %%
pattern_set = [
    ('url', re.compile(ur"((?:(?:https?|ftp|http)://)(?:\S+(?::\S*)?@)?(?:(?!(?:10|127)(?:.\d{1,3}){3})(?!(?:169.254|192.168)(?:.\d{1,3}){2})(?!172.(?:1[6-9]|2\d|3[0-1])(?:.\d{1,3}){2})(?:[1-9]\d?|1\d\d|2[01]\d|22[0-3])(?:.(?:1?\d{1,2}|2[0-4]\d|25[0-5])){2}(?:.(?:[1-9]\d?|1\d\d|2[0-4]\d|25[0-4]))|(?:(?:[a-z\\u00a1-\\uffff0-9]-*)*[a-z\\u00a1-\\uffff0-9]+)(?:.(?:[a-z\\u00a1-\\uffff0-9]-*)*[a-z\\u00a1-\\uffff0-9]+)*(?:.(?:[a-z\\u00a1-\\uffff]{2,})))(?::\d{2,5})?(?:/\S*)?)", re.IGNORECASE)),
    ('urn', re.compile(ur"(oai:[a-z0-9.][a-z0-9-.]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+)", re.IGNORECASE)),
    ('urn', re.compile(ur"\burn:[a-z0-9][a-z0-9-]{0,31}:[a-z0-9()+,\-.:=@;$_!*'%/?#]+", re.IGNORECASE)),
    ('uuid', re.compile(ur'([a-f\d]{8}(-[a-f\d]{4}){3}-[a-f\d]{12}?)', re.IGNORECASE)),
    ('doi', re.compile(ur"(10[.][0-9]{4,}(?:[/][0-9]+)*/(?:(?![\"&\\'])\S)+)", re.IGNORECASE))
]

# %%
# let's add the namespace stopwords
with open('../solr_superset/namespaces.txt', 'r') as f:
    exclude_namespaces = [r.strip() for r in f.readlines()]

# %% [markdown]
# identifier identification
#
# inconsistent urn patterns:
#
# - can't assume it starts with urn
# - can't assume it starts with three letters
# - can't really assume any of the chunks are of some known length
# - can't really assume any of the chunks are of some known structure (uuid, etc)
#
#
# xml:
#
# - xml resolvers are injecting repetitive namespace listings (or schemas)
#     that can be captured as urls in the pattern set
#     (see http://catalog.data.gov/harvest/object/5e8cda58-9ea1-4038-9a11-98088f8749fa)
# - iso codelists, the same
# - xml resolvers often come with an internal @guid/@uuid (which is good for foaf, linking, etc,
#     but bad for capturing noise)
# - some uuid/guids in the resolved xml do not retain the hyphenated structure (even within the same record)
#
#
# oh and you can't indiscriminately use @id in xpath searches in xml because that could be an explicit identifier (id="my-1234-value") instead of some internally required value (gml:id="d34555").

# %%
# a shallow fork of simhashindex (https://github.com/liangsun/simhash/blob/master/simhash/__init__.py)
# what we need to do, in a db-free test env, is retain more than the string and the hash of
# the string (we have the sha of the source, the string, and the simhash of the string)
# and a way to exclude a sha from the result set - find equivalent objects in another response

from multiprocessing import Pool
from collections import defaultdict

# todo: make a little bucket class? for the mapreduce
# this is repeating stuff. aaagh, ick.
class IndexBucket(object):
    def __init__(self, f=64, k=2):
        self.bucket = {}
        self.k = k
        self.f = f
    
    def add(self, obj_id, obj_str, simhash):
        """
        `obj_id` is a string
        `simhash` is an instance of Simhash
        """
        assert simhash.f == self.f

        for key in self.get_keys(simhash):
            v = '%x,%s|%s' % (simhash.value, obj_id, obj_str)

            self.bucket.setdefault(key, set())
            self.bucket[key].add(v)

    def delete(self, obj_id, obj_str, simhash):
        """
        `obj_id` is a string
        `simhash` is an instance of Simhash
        """
        assert simhash.f == self.f

        for key in self.get_keys(simhash):
            v = '%x,%s|%s' % (simhash.value, obj_id, obj_str)

            if v in self.bucket.get(key, set()):
                self.bucket[key].remove(v)
    
    @property
    def offsets(self):
        """
        You may optimize this method according to <http://www.wwwconference.org/www2007/papers/paper215.pdf>
        """
        return [self.f // (self.k + 1) * i for i in range(self.k + 1)]

    def get_keys(self, simhash):
        for i, offset in enumerate(self.offsets):
            m = (i == len(self.offsets) - 1 and 2 ** (self.f - offset) - 1 or 2 ** (self.offsets[i + 1] - offset) - 1)
            c = simhash.value >> offset & m
            yield '%x:%x' % (c, i)

    def bucket_size(self):
        return len(self.bucket)
    
    
class HashIndex(object):
    
    def _partition(self):
        # chunk out our store into smaller bits
        breakpoint = int(round(len(self.store) / self.workers + 0.5))
        i = 0
        while i < len(self.store):
            yield self.store[i:i+breakpoint]
            i += breakpoint
            
    def _map(self, arr, simhash):
        # make a bucket and compare the simhash to
        # that local set, return if distance < k
        bucket = IndexBucket(k=self.k, f=self.f)
        
        for i, q in enumerate(arr):
            self.add(*q)
    
        # do the comparison
        near_dupes = self.get_near_dups(bucket, simhash)
        
        # return tuples of object strings, distance scores
        return [tuple(n.split('|')) for n in near_dupes]
            
    def _reduce(self, mappings):
        # join and sort asc
        near_dupes = []
        
        # just run chain from_iterable on the lists of tuples to get a list of tuples
        # then sort by the distance
        
    
    # todo: shift this to the bucket and change to run the
    #       mapreduce instead (so partition, map, reduce)
    def get_near_dups(self, bucket, simhash):
        """
        `simhash` is an instance of Simhash
        return a list of obj_id (pipe-delimited string of sha|text|distance)
        """
        assert simhash.f == self.f

        ans = set()

        for key in self.get_keys(simhash):
            dups = bucket.get(key, set())

            for dup in dups:
                sim2, obj_blob = dup.split(',', 1)
                sim2 = Simhash(long(sim2, 16), self.f)

                d = simhash.distance(sim2)
                if d <= self.k:
                    ans.add('{0}|{1}'.format(obj_blob, d))
        return list(ans)

    def __init__(self, objs, f=64, k=2):
        """
        `objs` is a list of (sha, source obj (str), simhash)
        obj_id is a string, simhash is an instance of Simhash
        `f` is the same with the one for Simhash
        `k` is the tolerance
        """
        self.k = k
        self.f = f
        
        self.workers= 10
        #count = len(objs)
        
        self.store = objs 

    @property
    def offsets(self):
        """
        You may optimize this method according to <http://www.wwwconference.org/www2007/papers/paper215.pdf>
        """
        return [self.f // (self.k + 1) * i for i in range(self.k + 1)]

    def get_keys(self, simhash):
        for i, offset in enumerate(self.offsets):
            m = (i == len(self.offsets) - 1 and 2 ** (self.f - offset) - 1 or 2 ** (self.offsets[i + 1] - offset) - 1)
            c = simhash.value >> offset & m
            yield '%x:%x' % (c, i)

# %%
# notes: url regex drops the final } from the opensearch templates (should we care about the templates anyway?)

files = glob.glob('../testdata/solr_20150320/identify_20150325_p/*.json')

FOUND_LIMIT = 1000

all_identifiers = []

for f in files:
    with open(f, 'r') as g:
        data = json.loads(g.read())

    text = data.get('content').encode('unicode_escape')
    url = data.get('source_url')
    
    if 'DDI25' in url:
        continue
    
    sha_id = generate_sha(url)
    
    # extract the text from the xml
    try:
        parser = Parser(text)
    except Exception as ex:
        print ex
        continue
    
    identifiers = []
    simvalues = set()
    
    # process the tuples (tag, text)
    text_blobs = parser.strip_text()
    
    logger.debug('Processing for {0}: {1}'.format(url, len(text_blobs)))
    
    try:
        for tag_blob, text_blob in text_blobs:
            if not text_blob:
                continue

            for match_pttn, match_blob in process_text(text_blob):
                if match_blob in exclude_namespaces:
                    continue
                # add some simhash and match
                sh = Simhash(match_blob)
                if sh.value not in simvalues:
                    simvalues.add(sh.value)
                    #identifiers.append((sha_id, match_blob, sh))
                    identifiers.append((url, match_blob, sh))
    except Exception as ex:
        print url 
        print '\t', ex
        continue
            
    logger.debug('Processing for {0}: as XML'.format(url))
    
    for match_pttn, match_blob in match_identifier_rules(parser.xml):
        if not match_blob or match_blob in exclude_namespaces:
            continue
        
        sh = Simhash(match_blob)
        if sh.value not in simvalues:
            simvalues.add(sh.value)
            #identifiers.append((sha_id, match_blob, sh))
            identifiers.append((url, match_blob, sh))
        
    logger.debug('Processing for {0}: as url'.format(url))
    
    for match_pttn, match_blob in match_identifier_patterns(url):
        if not match_blob or match_blob in exclude_namespaces:
            continue
        
        sh = Simhash(match_blob)
        if sh.value not in simvalues:
            simvalues.add(sh.value)
            #identifiers.append((sha_id, match_blob, sh))
            identifiers.append((url, match_blob, sh))
    
    # for any identifier, add a tuple to {some store}
    # where today {some store} is some files on disk
    # note: simhashes can't be reloaded from a string/hex so 
    # i'm going to take the simhash index and make the keys not be strings 
    if not identifiers:
        continue
        
    all_identifiers += identifiers

#     with open(os.path.join('simhashing', os.path.basename(f)), 'w') as g:
#         g.write(json.dumps(identifiers, indent=4))
        
#     if len(glob.glob('simhashing/*.json')) > FOUND_LIMIT:
#         break
# Out:
# UNICODE fail:  10.5281/zenodo.15667.
# http://semantic-mediawiki.org/wiki/Special:Ask/-5B-5BNews-20date::%2B-5D-5D-20-5B-5Blanguage-20code::en-5D-5D/format%3Dfeed/sort%3Dnews-20date/order%3Ddesc/searchlabel%3DAtom/type%3Datom/title%3DSemantic-20MediaWiki-20%E2%80%93-20news/description%3DLatest-20news-20from-20semantic-2Dmediawiki.org/page%3Dfull/offset%3D0
# 	'ascii' codec can't decode byte 0xc3 in position 35: ordinal not in range(128)
# http://rss.nrdcfeeds.org/pulsoverde
# 	'ascii' codec can't decode byte 0xe2 in position 82: ordinal not in range(128)
# http://rss.nrdcfeeds.org/switchboard_all
# 	'ascii' codec can't decode byte 0xe2 in position 43: ordinal not in range(128)
# http://www.bibsonomy.org/burst/user/yish/analytics
# 	'ascii' codec can't decode byte 0xc3 in position 12: ordinal not in range(128)
# https://www2.le.ac.uk/search_rss?sort_on=sortable_title&Subject:list=Astronomy
# 	'ascii' codec can't decode byte 0xe2 in position 48: ordinal not in range(128)
# UNICODE fail:  http://idéemarque.ca
# http://planet.ffii.org/atom.xml
# 	'ascii' codec can't decode byte 0xc3 in position 47: ordinal not in range(128)
# UNICODE fail:  10.5281/zenodo.15667.
# http://www.w3.org/International/planet/atom.xml
# 	'ascii' codec can't decode byte 0xc4 in position 40: ordinal not in range(128)
# UNICODE fail:  10.5281/zenodo.15667.
# http://www.eurovelo.org/feed/rdf/
# 	'ascii' codec can't decode byte 0xc3 in position 55: ordinal not in range(128)
# UNICODE fail:  http://wellcomelibrary.org/content/documents/policy-documents/collection-development-policy.pdf [Accessed:
# UNICODE fail:  10.5281/zenodo.15667.

# %%
# from some 25K files, second harvest, extracted 642,610 things to hash

len(all_identifiers)

# all_identifiers[500:510]
# Out:
# 346631

# %%
import time

# additional blacklisting of things
# excludes = [
#     'http://purl.org/',
#     'http://www.w3.org',
#     'esri',  # do not use this because it could just be part of the route, but no worries today
#     'soap'
# ]

# let's play with our new indexer
RANGE = 1000
#for i, (sha_id, text_blob, simhash) in enumerate(all_identifiers[200:250]):
for i, (url, text_blob, simhash) in enumerate(all_identifiers[6010:7300]):
#     if sum([1 for e in exclude_namespaces if text_blob.lower().find(e) >= 0]) > 0:
#         continue
    
        
    print url, text_blob
    
    sha = generate_sha(url)
    
    start_time = time.time()
    
    near_dupes = []
    
    for x in xrange(0, len(all_identifiers), RANGE):
        test_set = [d for d in all_identifiers[x:x+RANGE] if d[0] != url]
        index = HashIndex(test_set, k=0)
        
        dupes = [d.split('|') for d in index.get_near_dups(simhash)]
    
        if len(dupes) > 0:
            # sha, text, distance
            near_dupes.extend([(d[0], d[1]) for d in dupes if int(d[2]) < 1])
    
    if near_dupes:
        with open(os.path.join('simhashing_near_dupes', '{0}.txt'.format(sha)), 'a') as f:
            f.write('Source URL: {0}\nMatch blob: {1}\nSource Simhash: {2}\n\n'.format(url, text_blob, 
                                                                                       simhash.value))
            f.write(json.dumps(near_dupes, indent=4)+'\n\n')
    
        print '\t', len(near_dupes), time.time() - start_time
        print
# Out:
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1114
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 12DD2C2A-3535-4EBB-BAE5-3616A3BA3145
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1113
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 896580DE-8E67-439B-B37E-BDD472921EF9
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1112
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 601E33EF-B00D-437A-9DD2-647B5CED55EA
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1111
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD BC5A2AFC-E452-4DA5-91A0-F3D321869E50
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1110
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 751FFEB7-2414-413F-B4D4-2EC089FFA00A
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1109
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 6E6F1E1E-B575-4D82-8347-6DB2A69D1102
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1108
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 4ABD128C-AE09-4774-AD48-D348AC0108BA
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1107
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD EC6F8316-C7C8-4C45-8FE3-B5B19348C9FA
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1106
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 0D765AEF-24D9-44C2-807F-46D955EB421B
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1105
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 0379E281-128F-4CC1-91B9-1C33B94F70DE
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1104
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 7470FDB5-E2E2-4DE7-9E6E-FCCBAB11709C
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1103
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 78DC74D5-4072-444D-A14D-9112E6CD0825
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1102
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 56B32A3B-5E99-4C05-B512-F40DF26153A4
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1101
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 113AF141-D960-4DE6-ACF5-9784FEBE2052
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1100
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 067EAB5D-BCFB-4BF9-8A8B-9ACDF0C6F425
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1099
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 32CD4626-FF0D-4980-AE50-E51A467215C9
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1098
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD FCA6D051-669E-4D9D-B671-2540FE720863
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1094
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD E25E9C7F-02C1-4908-B67B-AD568DA2CBC4
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1097
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 0A088E18-C45F-4FCA-9986-F4A28BCEE2E7
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1096
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD E8B0D5D1-1D90-4DAB-ABEA-83E4ABF5F9AA
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1095
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 1EB91986-3893-43D5-883C-EACF878905CD
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1093
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 236D397F-70DE-466F-A588-23BE3F34C094
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1092
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD FC605F27-4EB0-4EE6-A66E-D2FD4E34EE8B
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1091
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD F4241CD8-1E77-4A33-B8FB-CA4B32024171
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD EE744715-84AC-4181-ABF4-E71761451B99
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1089
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 999917B4-EB99-485C-B82D-C229A1A808F4
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1088
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 5F60143F-8A1B-4F92-B915-9AB1D3CF7754
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/1087
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD 2C564C1A-509A-4B28-915B-3F7BC9DBB953
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/441
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD F323F3FE-F020-481E-8FCF-E29A1F9448D2
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/439
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD C68AE758-F158-48A0-882E-4FC94E85C7F9
# https://data.cityofchicago.org/api/views/s7ek-ru5b/rows.xml?accessType=DOWNLOAD http://data.cityofchicago.org/resource/s7ek-ru5b/438

# %% [markdown]
# some urn uuid examples:
#
# http://uaf.nodc.noaa.gov/geoportal/rest/find/document?max=5&f=atom&searchText=
#
# cdata fun:
#
# http://ngdc.noaa.gov/geoportal/rest/find/document?searchText=

# %%
import os
import json

with open('../testdata/solr_20150320/simhash_results_b.txt', 'r') as f:
    lines = f.readlines()

x = []
for line in lines[5:15]:
    data = json.loads(line.strip())
    x.append(data)

x
# Out:
# [{u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.03.07.L3.RetStd008.v6.0.9.0.G13095171139.hdf.ncml': [u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.03.07.L3.RetStd008.v6.0.9.0.G13095171139.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STD.005/2012/AIRS.2012.01.02.L3.RetStd001.v5.2.2.0.G12012154026.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2013/AIRS.2013.02.01.L3.RetStd_IR028.v6.0.9.0.G13096014834.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2010/AIRS.2010.03.15.L3.RetStd008.v6.0.9.0.G13085172737.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.01.10.L3.RetStd008.v6.0.9.0.G13092175516.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2009/AIRS.2009.01.23.L3.RetStd008.v6.0.9.0.G13091222502.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2009/AIRS.2009.11.01.L3.RetStd_IR030.v6.0.9.0.G14016210017.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2006/AIRS.2006.02.01.L3.RetStd_IR028.v6.0.9.0.G13273175026.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3ST8.006/2014/AIRS.2014.01.05.L3.RetStd_IR008.v6.0.11.0.G14097174729.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STD.005/2012/AIRS.2012.01.04.L3.RetStd001.v5.2.2.0.G12006143931.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2005/AIRS.2005.06.01.L3.RetStd_IR030.v6.0.9.0.G13259141534.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.03.07.L3.RetStd008.v6.0.9.0.G13095171139.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2004/AIRS.2004.08.01.L3.RetStd_IR031.v6.0.9.0.G13241032758.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.01.10.L3.RetStd008.v6.0.9.0.G13092175516.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3ST8.006/2013/AIRS.2013.03.07.L3.RetStd_IR008.v6.0.9.0.G13095161516.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2011/AIRS.2011.04.01.L3.RetStd030.v6.0.9.0.G13068114446.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2011/AIRS.2011.03.02.L3.RetStd008.v6.0.9.0.G13067221654.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2002/AIRS.2002.11.04.L3.RetStd008.v6.0.9.0.G13209121513.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2003/AIRS.2003.04.01.L3.RetStd_IR030.v6.0.9.0.G13225191158.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2004/AIRS.2004.04.01.L3.RetStd_IR030.v6.0.9.0.G13235160524.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM.006/2008/AIRS.2008.09.01.L3.RetStd_IR030.v6.0.9.0.G14065181323.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STD.006/2006/AIRS.2006.01.01.L3.RetStd001.v6.0.9.0.G13140214834.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3ST8.006/2013/AIRS.2013.01.02.L3.RetStd_IR008.v6.0.9.0.G13094011450.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2004/AIRS.2004.01.10.L3.RetStd008.v6.0.9.0.G13171200954.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2004/AIRS.2004.01.26.L3.RetStd008.v6.0.9.0.G13207171424.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STD.006/2011/AIRS.2011.01.06.L3.RetStd001.v6.0.9.0.G13066174205.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3ST8.006/2013/AIRS.2013.02.03.L3.RetStd008.v6.0.9.0.G13120150737.hdf.ncml.ddx',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3ST8.006/2004/AIRS.2004.03.06.L3.RetStd_IR008.v6.0.9.0.G13235011532.hdf.ncml',
#    u'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRS3STM
/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43C1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/MYD02HKM/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCFR_C20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/OZ_DAILY/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCTP_C05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3147/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MOB11_L2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3150/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCTP_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/D4LAXMNT/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43B2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCPH_W20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3002/NPP_D17RNDVIS_L3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43B4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCIR_C20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOD09Q1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09Q1P19_NDVI/2004/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/BRDF_DB/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB43A4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCPH_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09Q1P19_EVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43C4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MOD11A1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB15A3F/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/TOAST/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD15A2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/BGRND_NQD_LWM/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3001/NCEP_GFS06_ANC/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MOB09A1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCPH_C20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD08_M3_NC/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOD09Q1/2010/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09A1P19_NDVI/2004/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOD09Q1P_EVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1P_NDVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3154/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCIR_W20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09Q1P19_EVI/2005/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3002/NAAPS_TODIP_L2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3144/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOB09Q1P19_EVI/2005/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3100/NPP_NAAPS_03H/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43C2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MOB09Q1GC_EVI/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCOT_W05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCIR_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/MOD01/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB43B3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09A1P_NDVI/2004/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MOB11A1D/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3100/NPP_USNOPW/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB43B4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCIR_W20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3152/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOB09Q1P19_EVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB15A2L/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCOT_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1P_NDVI/2004/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43A4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCPH_W05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3100/NPP_VIIRS_L0/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCTT_C05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43C3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3002/NPP_D17LALBIP_L3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D13/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCPH_W05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MYB11C3D/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3110/NAAPS_TODIP_L2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB15A2F/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3000/NP5_CMIP_L2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBCTP/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09A1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MOB11C3N/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43B3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGPLI_C/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D21/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCB15A3L/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBCOT/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCOT_W20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/OZONEEP/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09A1P_NDVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43A1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3000/NP5_SVM14_L1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCFR_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCIR_C05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCFR_C20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCOT_E05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MOB11C3D/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCOT_W05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3146/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGPST_C/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09Q1GC_EVI/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD12Q1/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/MYD11C3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D33/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MOB09Q1G_NDVI/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBCTP_E3/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3149/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBCIR_C00/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/3001/NAAPS_TODIP_L2/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D25/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1P_EVI/2004/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D16/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/MCD43D23/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCPH_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/41/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1P_NDVI/2005/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09A1G_NDVI/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCIR_C05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCFR_E05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCIR_E20K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/4/ALBWS213/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/5/ALBWS164/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBGCTP_W05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOD09Q1P_EVI/2001/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/6/MOBGCPH_C05K/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/55/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/51/MOBCER/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/1003/MOB09Q1P19_EVI/2009/catalog.xml',
#    u'http://ladsweb.nascom.nasa.gov/opendap/allData/404/MOB09Q1G_NDVI/catalog.xml']}]

# %%
from simhash import Simhash

h1 = Simhash('https://pypi.python.org/pypi?:action=doap&name=lzmaffi&version=0.2.0')
h2 = Simhash('http://disc2.nascom.nasa.gov/opendap/TRMM_L3/TRMM_3A46/2002/152/3A46.020601.2.HDF.Z.rdf')
h3 = Simhash('http://mrdata.usgs.gov/wfs/agdb2?request=GetCapabilities&service=WFS&version=1.0.0')
h4 = Simhash('https://wiki.ucar.edu/opensearch/osd.action')

h1.distance(h4)
# Out:
# 19

# %% [markdown]
# daniel's idea:
#
# split the url
# sort
# concatenate
# simhash the string
# compare
#
# i am going to drop the scheme and possibly the host (two tests, then).
# i am also going to do route parts + query parameter values only (how to deal with urls in the query parameters).
#
# not sure how to run this for non-url/uri structures right now

# %%
from simhash import Simhash, SimhashIndex
import urlparse


acdiscs = [
'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml',
'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml.ddx',
'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/catalog.xml',
'http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/catalog.xml',
'http://acdisc.sci.gsfc.nasa.gov/opendap/Nimbus7_TOMS_Level3/TOMSN7L3.008/catalog.xml',
'http://api.gbif.org/v1/dataset/50c9509d-22c7-4a22-a47d-8c48425ef4a7/document'
]

# as original, new, simhash
compares = []
for a in acdiscs:
    parts = urlparse.urlparse(a)
    
    s = [parts.netloc] + [p for p in parts.path.split('/') if p and p != '/']

    s = sorted(s)
    
    new_a = ''.join(s)
    
    compares.append((a, new_a, Simhash(new_a)))
    
#print compares    

index = HashIndex(compares, k=5)

dupes = index.get_near_dups(compares[0][2])

dupes = [d.split('|') for d in dupes]

print 'from resort:'
[(d[0], d[2]) for d in dupes]
# Out:
# from resort:
# [('http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml.ddx',
#   '2'),
#  ('http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml',
#   '0')]

# %%
# as original, new, simhash
compares = []
for a in acdiscs:
    parts = urlparse.urlparse(a)
    
    s = [parts.netloc] + [p for p in parts.path.split('/') if p and p != '/']
    
    new_a = ''.join(s)
    
    compares.append((a, new_a, Simhash(new_a)))  

index = HashIndex(compares, k=5)

dupes = index.get_near_dups(compares[0][2])

dupes = [d.split('|') for d in dupes]

print 'without sort:'
[(d[0], d[2]) for d in dupes]
# Out:
# without sort:
# [('http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml.ddx',
#   '3'),
#  ('http://acdisc.sci.gsfc.nasa.gov/opendap/ncml/Aqua_AIRS_Level3/AIRX3STM.006/2015/AIRS.2015.02.01.L3.RetStd028.v6.0.11.0.G15076164741.hdf.ncml',
#   '0')]

# %%
# what about splitting on lots of punctuation?

import re

# as original, new, simhash
compares = []
for a in acdiscs:
    parts = urlparse.urlparse(a)
    
    s = [parts.netloc] + [p for p in parts.path.split('/') if p and p != '/']

    s = sorted(s)
    
    new_a = ''.join(s)
    
    compares.append((a, new_a, Simhash(new_a)))
    
#print compares    

index = HashIndex(compares, k=5)

dupes = index.get_near_dups(compares[0][2])

dupes = [d.split('|') for d in dupes]

print 'from resort:'
[(d[0], d[2]) for d in dupes]

# %% [markdown]
# ## urn examples (best list, incomplete list)
#
# some list from the data and other sources to come up with some regexes to id those
#
# worst case scenario = word break str:str:str:str word break
#
#
# this:
# (([a-z0-9.][a-z0-9-.]{0,}:)+[a-z0-9()+,\-.:=@;$_!*'%/?#]+)
# captures this:
# blob="oai:openknowledge.worldbank.org:10986/18612"
#
#
# todo:
# generate a csv of [sha, url, text, pattern matched] for the full set of things
# poke around in it - does it look decent (no cruft, etc)
# run the extract xml task for everything (needs workflow) for easier poking about as well
# run the full identify everything with no drops for generic xml
# use that for the bag of words extraction (we're running two types, ugh)
# finish the few changes to the local simhash (rename and setup.py)
# stand up the aws for the db
# set up the tasks for extracting and dumping to db (might need something goofy in luigi)

# %%
s1 = 'urn:ogc:def:crs:EPSG::4979'
s2 = 'oai:openknowledge.worldbank.org:10986/18612'
s3 = 'blob="oai:openknowledge.worldbank.org:10986/18612"'

import re

pttn = re.compile(ur"([a-z0-9.][a-z0-9-.]{0,}:)+[a-z0-9()+,\-.:=@;$_!*'%/?#]+", re.IGNORECASE)
match(s3, pttn)
# Out:
# 'oai:openknowledge.worldbank.org:10986/18612'
