# %% [markdown]
# ### new identification widgetry

# %%
# %reload_ext autoreload
# %autoreload 2

import os
import json
import re
from itertools import chain
from semproc.yaml_configs import import_yaml_configs
from semproc.parser import Parser
from semproc.rawresponse import RawResponse

# %%
class Identify():
    '''
    parameters:
        yaml_file: path to the yaml definition yaml
        source_content: the content string for comparisons
        source_url: the url string for comparisons
        options: dict containing the filtering options, ie
                 identify which protocol, identify which service
                 of a protocol, identify if it's a dataset service
                 for a protocol
    '''
    def __init__(self, yaml_files, source_content, source_url):
        '''
        **options:
            parser: Parser from source_content
            ignore_case: bool
        '''
        self.source_content = source_content
        self.source_url = source_url
        self.yaml = import_yaml_configs(yaml_files)
        
        self.parser = Parser(source_content)
        

    def _filter(self, operator, filters, clauses):
        '''
        generate a list of dicts for operator and booleans
        that can be rolled up into some bool for a match
        '''
        for f in filters:
            filter_type = f['type']

            if filter_type == 'complex':
                filter_operator = f['operator']
                clauses.append(self._filter(filter_operator, f['filters'], []))
            elif filter_type == 'simple':
                filter_object = self.source_content if f['object'] == 'content' else self.source_url
                filter_value = f['value']

                # TODO: a better solution than this
                filter_value = filter_value.upper()
                filter_object = filter_object.upper()
                
                clauses.append(filter_value in filter_object)
            elif filter_type == 'regex':
                filter_object = self.source_content if f['object'] == 'content' else self.source_url
                filter_value = f['value']
                clauses.append(len(re.findall(filter_value, filter_object)) > 0)
            elif filter_type == 'xpath':
                # if the filter is xpath, we can only run against
                # the provided xml (parser) and ONLY evaluate for existence
                # ie the xpath returned some element, list, text value
                # but we don't care what it returned
                xpath = f['value']
                if not self.parser:
                    # nothing to find, this is an incorrect filter
                    clauses.append(False)

                # try the xpath but there could be namespace or
                # other issues (also false negatives!)
                try:
                    clause = self.parser.xml.xpath(xpath) not in [None, '', []]
                except:
                    clause = False

                clauses.append(clause)

        return {operator: clauses}

    def _evaluate(self, clauses, sums):
        '''
        evaluate a list a dicts where the key is
        the operator and the value is a list of
        booleans
        '''
        if isinstance(clauses, bool):
            # so this should be the rolled up value
            return clauses

        for k, v in clauses.iteritems():
            if isinstance(v, dict):
                return sums + self._evaluate(v, 0)
            elif isinstance(v, list) and not all(isinstance(i, bool) for i in v):
                # TODO: this is not a good assumption
                for i in v:
                    sums += self._evaluate(i, 0)
                return sums
            if k == 'ands':
                # everything must be true
                sums += sum(v) == len(v)
            elif k == 'ors':
                # any one must be true
                sums += sum(v) > 0

        return sums

    def identify(self):
        '''
        it is within a protocol if *any* set of filters
        '''
        def _test_option(filters):
            '''where filters is the set of filters as booleans'''
            if not filters:
                return False
            
            for i, j in filters.iteritems():
                if self._evaluate({i: self._filter(i, j, [])}, 0):
                    return True
                
            return False
        
        def _extract_option(filters):
            '''
            where filters is the set of things to return a value
            this assumes that you have concatenated the defaults and/or checks set
            '''
            if not filters:
                return []
            
            items = []
            for check in filters:
                for c in check[1]:
                    item = ''
                    if c['type'] == 'simple':
                        # TODO: this is still not a safe assumption re: casing
                        filter_value = c['value'].upper()
                        filter_object = self.source_content if c['object'] == 'content' else self.source_url
                        filter_object = filter_object.upper()
                        
                        if filter_value in filter_object:
                            item = [c.get('text', '')]  # just for the xpath handling later
                    elif c['type'] == 'xpath':
                        if not self.parser.xml:
                            print 'Parser FAIL'
                            continue
                        
                        try:
                            values = self.parser.xml.xpath(c['value'])
                            item = [v.strip() for v in values if v is not None]
                        except Exception as ex:
                            print 'XPATH FAIL: ', ex 
                            print c['value']
                            continue
                    
                    if item:
                        items += item
            
            return items
        
        def _chain(source_dict, keys):
            if not source_dict:
                return []
            return list(chain.from_iterable(
                    [source_dict.get(key, {}).items() for key in keys]
                ))
        
        matches = []
        for protocol in self.yaml:
            protocol_name = protocol['name']

            for k, v in protocol.iteritems():
                if k in ['name'] or v is None:
                    continue
                
                print k['name']
                
                for option in v:
                    is_match = _test_option(option['filters'])
                            
                    # check the error filters
                    errors = option.get('errors', {})
                    is_error = _test_option(errors.get('filters', {})) if errors else False

                    # check the language filters
                    language_filters = option.get('language', {})
                    _filters = _chain(language_filters, ["defaults", "checks"])
                    languages = _extract_option(_filters)

                    # check the version filters
                    version_filters = option.get('versions', {})
                    _filters = _chain(version_filters, ["defaults", "checks"])
                    versions = _extract_option(_filters)

                    # dump it out
                    if is_match:
                        matches.append({
                                "protocol": protocol_name, 
                                "type": k,
                                "type_name": option.get('name', ''),
                                "request": option.get('request', ''),
                                "version": versions,
                                "error": is_error,
                                "language": languages
                            })

        return matches

# %%
import glob

with open('../response_examples/opensearch_blended_parameters.xml', 'r') as f:
    response = f.read()

response = response.replace('\\\n', '').replace('\r\n', '').replace('\\r', '').replace('\\n', '').replace('\n', '')
response = response.decode('utf-8', errors='replace').encode('unicode_escape')

# print response

url = 'http://www.example.com/opensearch.xml'
yamls = glob.glob('../semproc/configs/*_identifier.yaml')
# yamls = ['../semproc/configs/opensearch_identifier.yaml', 
#          '../semproc/configs/iso_identifier.yaml',
#         '..']

identifier = Identify(yamls, response, url)
identifier.identify()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-23893a1b4a4e> in <module>()
#      16
#      17 identifier = Identify(yamls, response, url)
# ---> 18 identifier.identify()
#
# <ipython-input-103-ad0d2eef5aae> in identify(self)
#     163                     continue
#     164
# --> 165                 print k['name']
#     166
#     167                 for option in v:
#
# TypeError: string indices must be integers, not str

# %%
identifier.yaml
# Out:
# [{'datasets': None,
#   'errors': None,
#   'filters': {'ors': [{'object': 'content',
#      'type': 'simple',
#      'value': 'http://www.w3.org/2005/Atom'}]},
#   'metadatas': None,
#   'name': 'ATOM',
#   'service_description': None,
#   'subtype': 'service',
#   'versions': None},
#  {'metadata': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.openarchives.org/OAI/2.0/oai_dc/'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name() = "dc"]'}]},
#     'name': 'DublinCore',
#     'versions': {'defaults': {'ors': [{'object': 'content',
#         'text': '2.0',
#         'type': 'simple',
#         'value': 'http://www.openarchives.org/OAI/2.0/oai_dc/'}]}}}],
#   'name': 'DC'},
#  {'metadata': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="DIF"]'},
#       {'object': 'content', 'type': 'simple', 'value': '<Entry_ID>'}]},
#     'name': 'DIF',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': 'concat(/*/*[local-name()="Metadata_Name"], /*/*[local-name()="Metadata_Version"])'}]}}}],
#   'name': 'DIF'},
#  {'name': 'PDS',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://pds.nasa.gov/pds4/pds/v1'}]},
#     'name': 'PDS'}]},
#  {'name': 'CAP-ALERT',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.incident.com/cap/1.0'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'urn:oasis:names:tc:emergency:cap:'}]},
#     'name': 'CAP-ALERT'}]},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.loc.gov/MARC21/slim'}]},
#     'name': 'MARC 21 Format'}],
#   'name': 'MARC 21 Format'},
#  {'metadata': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.ddialliance.org/Specification/DDI-Codebook'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="codeBook"]'}]},
#     'name': 'DDI'}],
#   'name': 'DDI'},
#  {'dataset': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://earth.google.com/kml'}]},
#     'name': 'KML'}],
#   'name': 'KML'},
#  {'name': 'ArcGISExplorerDocument',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.esri.com/schemas/ArcGIS/'}]},
#     'name': 'ArcGISExplorerDocument'}]},
#  {'name': 'ESRI MapServer Info',
#   'service': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'EsriPropertyType='},
#       {'object': 'content', 'type': 'simple', 'value': 'ArcGISFormat'},
#       {'object': 'content', 'type': 'simple', 'value': '<Esri>'}]},
#     'name': 'ESRI MapServer Info'}]},
#  {'dataset': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'urn:schemas-microsoft-com:office:office'}]},
#     'name': 'Microsoft Document'}],
#   'name': 'Microsoft'},
#  {'name': 'WordPress',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://archipelago.phrasewise.com/rsd'},
#       {'object': 'url', 'type': 'simple', 'value': '?rsd'},
#       {'object': 'url', 'type': 'simple', 'value': 'rsd.xml'}]},
#     'name': 'WordPress'}]},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.loc.gov/METS_Profile/'}]},
#     'name': 'LOC-METS'}],
#   'name': 'LOC-METS'},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://datacite.org/schema/'}]},
#     'name': 'DataCite'}],
#   'name': 'DataCite'},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'eml://ecoinformatics.org/eml-'}]},
#     'name': 'EML'}],
#   'name': 'EML'},
#  {'name': 'QuakeML',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://anss.org/xmlns/catalog'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://anss.org/xmlns/tensor'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://quakeml.org/xmlns/bed/'}]},
#     'name': 'QuakeML'}]},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://niem.gov/'}]},
#     'name': 'NIEM'}],
#   'name': 'NIEM'},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://schemas.xmlsoap.org/disco/'}]},
#     'name': 'Disco'}],
#   'name': 'Disco'},
#  {'name': 'SOAP',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://schemas.xmlsoap.org/soap'}]},
#     'name': 'SOAP'}]},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.google.com/geo/schemas/sitemap/'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.sitemaps.org/schemas/sitemap/'}]},
#     'name': 'Sitemap'}],
#   'name': 'Sitemap'},
#  {'name': 'iTunes',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.itunes.com/dtds/podcast-1.0.dtd'}]},
#     'name': 'iTunes'}]},
#  {'name': 'waterML',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.cuahsi.org/waterML/'}]},
#     'name': 'waterML'}]},
#  {'name': 'ECHO',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://echo.nasa.gov/'}]},
#     'name': 'ECHO'}]},
#  {'name': 'MODAPS',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://modapsws.gsfc.nasa.gov/xsd'}]},
#     'name': 'MODAPS'}]},
#  {'name': 'IOOS',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.noaa.gov/ioos/'}]},
#     'name': 'IOOS'}]},
#  {'name': 'Zenodo',
#   'service': [{'filters': {'ors': [{'object': 'url',
#        'type': 'simple',
#        'value': 'zenodo.org/'}]},
#     'name': 'Zenodo'}]},
#  {'name': 'Ferret ToolsUi',
#   'service': [{'filters': {'ors': [{'object': 'url',
#        'type': 'simple',
#        'value': 'http://ferret.pmel.noaa.gov/thredds/view/ToolsUI.jnlp?'}]},
#     'name': 'Ferret ToolsUI'}]},
#  {'file': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'xmlns:xs="http://www.w3.org/2001/XMLSchema'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="schema"] and //*[local-name()="element"]'}]},
#     'name': 'XSD'}],
#   'name': 'XSD'},
#  {'file': [{'filters': {'ands': [{'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="HDF5-File"]'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'xmlns:hdf5="http://hdfgroup.org/DTDs/HDF5-File'}]},
#     'name': 'HDF-XML'}],
#   'name': 'HDF-XML'},
#  {'metadata': [{'filters': {'ors': [{'object': 'content',
#        'type': 'xpath',
#        'value': '/metadata/metainfo/metstdv[text()="FGDC-STD-001-1998"]'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/metadata/metainfo/metstdv[text()="FGDC-STD-012-2002"]'}]},
#     'name': 'FGDC',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': 'concat(//metstdn/text(), ", ", //metstdv/text())'}]}}}],
#   'name': 'FGDC'},
#  {'metadata': [{'filters': {'ors': [{'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "MI_Metadata"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns="http://www.isotc211.org/2005/gmi'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "MD_Metadata"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns="http://www.isotc211.org/2005/gmd'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "MI_Metadata"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns:gmi="http://www.isotc211.org/2005/gmi"'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "MD_Metadata"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns:gmd="http://www.isotc211.org/2005/gmd"'}],
#        'operator': 'ands',
#        'type': 'complex'}]},
#     'language': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '/*/*[local-name()="language"]/*[local-name()="CharacterString"]/text()'}]}},
#     'name': '19115',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': 'concat(/*/*[local-name()="metadataStandardName"]/*[local-name()="CharacterString"]/text(), " ", /*/*[local-name()="metadataStandardVersion"]/*[local-name()="CharacterString"]/text())'}]}}},
#    {'filters': {'ors': [{'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "DS_Series"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns="http://www.isotc211.org/2005/gmi"'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'filters': [{'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name() = "DS_Series"]'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': 'xmlns="http://www.isotc211.org/2005/gmd"'}],
#        'operator': 'ands',
#        'type': 'complex'}]},
#     'language': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '/*/*[local-name()="language"]/*[local-name()="CharacterString"]/text()'}]}},
#     'name': 'Data Series',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': 'concat(/*/*[local-name()="seriesMetadata"]/*[local-name()="MD_Metadata" or local-name()="MI_Metadata"]/*[local-name()="metadataStandardName"]/*[local-name()="CharacterString"]/text(), " ", /*/*[local-name()="seriesMetadata"]/*[local-name()="MD_Metadata" or local-name()="MI_Metadata"]/*[local-name()="metadataStandardVersion"]/*[local-name()="CharacterString"]/text())'}]}}},
#    {'filters': None, 'name': '19119', 'versions': None}],
#   'name': 'ISO'},
#  {'name': 'OAI-PMH',
#   'resultset': [{'dialect': {'checks': {'ors': [{'type': 'xpath',
#         'value': '//*/*[local-name()="request"]/@*[local-name()="metadataPrefix"]'}]}},
#     'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': '<ListRecords>'},
#       {'object': 'content', 'type': 'simple', 'value': 'verb="ListRecords"'}]},
#     'name': '',
#     'request': 'ListRecords'}],
#   'service': [{'errors': {'filters': {'ors': [{'object': 'content',
#         'type': 'simple',
#         'value': '<error code="'}]}},
#     'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'xmlns="http://www.openarchives.org/OAI/'},
#       {'object': 'url', 'type': 'simple', 'value': 'VERB=IDENTIFY'},
#       {'object': 'content', 'type': 'simple', 'value': '<Identify>'}]},
#     'name': 'Identify',
#     'request': 'Identify',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '/*/[local-name()="Identify"]/*[lcoal-name()"protocolVersion"]/text()'}]}}}]},
#  {'dataset': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wms'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': '<!DOCTYPE WMT_MS_Capabilities SYSTEM "http://schemas.opengis.net/wms/1.1.1/WMS_MS_Capabilities.dtd"'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WMS',
#     'request': 'GetCapabilities'},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wcs'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=DESCRIBECOVERAGE'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': '<CoverageDescription'}]},
#     'name': 'WCS',
#     'request': 'DescribeCoverage'},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wfs'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WFS',
#     'request': 'GetCapabilities'},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/sos'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'Operation name="DescribeSensor"'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'SOS',
#     'request': 'GetCapabilities'}],
#   'name': 'OGC',
#   'resultset': [{'dialect': {'checks': {'ors': [{'type': 'xpath',
#         'value': '//*/*[local-name()="SearchResults"]/@*[local-name()="recordSchema"]'}]}},
#     'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'GetRecordsResponse'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/cat/csw/'}]},
#     'name': 'CSW',
#     'request': 'GetRecords'}],
#   'service': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wms'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': '<!DOCTYPE WMT_MS_Capabilities SYSTEM "http://schemas.opengis.net/wms/1.1.1/WMS_MS_Capabilities.dtd"'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WMS',
#     'request': 'GetCapabilities',
#     'versions': {'checks': {'ors': [{'type': 'xpath', 'value': '@version'}]}}},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wcs'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WCS',
#     'request': 'GetCapabilities',
#     'versions': {'checks': {'ors': [{'type': 'xpath', 'value': '@version'}]}}},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wfs'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WFS',
#     'request': 'GetCapabilities'},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/sos'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'Operation name="DescribeSensor"'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'SOS',
#     'request': 'GetCapabilities'},
#    {'filters': {'ors': [{'filters': [{'object': 'content',
#          'type': 'simple',
#          'value': 'http://www.opengis.net/cat/csw'},
#         {'object': 'content', 'type': 'simple', 'value': '<csw:Capabilities'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'filters': [{'object': 'content',
#          'type': 'simple',
#          'value': 'http://www.opengis.net/cat/csw'},
#         {'object': 'url', 'type': 'simple', 'value': 'SERVICE=CSW'}],
#        'operator': 'ands',
#        'type': 'complex'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'CSW',
#     'request': 'GetCapabilities'},
#    {'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.opengis.net/wmts'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'Operation name="GetTile"'},
#       {'object': 'url', 'type': 'simple', 'value': 'REQUEST=GETCAPABILITIES'},
#       {'object': 'content', 'type': 'simple', 'value': '<GetCapabilities>'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'name="GetCapabilities"'}]},
#     'name': 'WMTS',
#     'request': 'GetCapabilities'}]},
#  {'dataset': [{'errors': {'filters': {'ors': [{'object': 'content',
#         'type': 'simple',
#         'value': '<property name="requires_authorization"'},
#        {'object': 'content',
#         'type': 'simple',
#         'value': '<variables vocabulary='},
#        {'object': 'content', 'type': 'simple', 'value': '<dap:Error'},
#        {'object': 'content',
#         'type': 'xpath',
#         'value': '/*[local-name()="Error"]'}]}},
#     'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://xml.opendap.org/ns/DAP'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.unidata.ucar.edu/namespaces/netcdf/ncml-'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="netcdf"]'}]},
#     'name': 'NCML'}],
#   'metadata': [{'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://xml.opendap.org/ns/DAP'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="Dataset"]'}],
#      'errors': {'filters': {'ors': [{'object': 'content',
#          'type': 'simple',
#          'value': '<property name="requires_authorization"'},
#         {'object': 'content',
#          'type': 'simple',
#          'value': '<variables vocabulary='},
#         {'object': 'content', 'type': 'simple', 'value': '<dap:Error'},
#         {'object': 'content',
#          'type': 'xpath',
#          'value': '/*[local-name()="Error"]'}]}}},
#     'name': 'DDX'}],
#   'name': 'OPeNDAP'},
#  {'metadatas': None,
#   'name': 'OpenSearch',
#   'resultset': [{'dialect': 'ATOM',
#     'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': '"http://a9.com/-/spec/opensearch/1.1/"'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.w3.org/2005/Atom'},
#       {'object': 'content', 'type': 'simple', 'value': '<feed'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '//*/*[local-name()="itemsPerPage"]'}]}}],
#   'service': [{'errors': {'filters': {'ors': [{'object': 'content',
#         'type': 'simple',
#         'value': 'OpenSearch Exception'},
#        {'object': 'content',
#         'type': 'simple',
#         'value': 'REQUEST_EXCEPTION:'}]}},
#     'filters': {'ands': [{'object': 'content',
#        'type': 'simple',
#        'value': 'xmlns="http://a9.com/-/spec/opensearch/1.1/"'},
#       {'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="OpenSearchDescription"]'}]},
#     'language': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '/*/*[local-name()="Language"]/text()'}]}},
#     'name': 'OpenSearchDescription',
#     'versions': {'defaults': {'ors': [{'object': 'content',
#         'text': '1.1',
#         'type': 'simple',
#         'value': 'http://a9.com/-/spec/opensearch/1.1/'}]}}}]},
#  {'dataset': [{'filters': {'ands': [{'object': 'content',
#        'type': 'xpath',
#        'value': '/*[local-name()="RDF"]'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#'},
#       {'object': 'content',
#        'type': 'simple',
#        'value': '<dcat:Dataset rdf:about='}]},
#     'language': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '@xml:lang'}]}},
#     'name': 'RDF',
#     'request': ''}],
#   'name': 'RDF'},
#  {'name': 'UNIDATA',
#   'service': [{'errors': {'filters': {'ors': [{'object': 'content',
#         'type': 'simple',
#         'value': '<property name="requires_authorization"'},
#        {'object': 'content',
#         'type': 'simple',
#         'value': '<variables vocabulary='},
#        {'object': 'content', 'type': 'simple', 'value': '<dap:Error'},
#        {'object': 'content',
#         'type': 'xpath',
#         'value': '/*[local-name()="Error"]'}]}},
#     'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://www.unidata.ucar.edu/namespaces/thredds/InvCatalog/v1.0'}]},
#     'name': 'THREDDS-Catalog',
#     'versions': {'checks': {'ors': [{'object': 'content',
#         'type': 'xpath',
#         'value': '@version'}]},
#      'defaults': {'ors': [{'object': 'content',
#         'text': '1.0',
#         'type': 'simple',
#         'value': 'http://www.unidata.ucar.edu/namespaces/thredds/InvCatalog/v1.0'}]}}}]},
#  {'name': 'WADL',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://wadl.dev.java.net'}]},
#     'name': 'WADL',
#     'request': ''}]},
#  {'name': 'WSDL',
#   'service': [{'filters': {'ors': [{'object': 'content',
#        'type': 'simple',
#        'value': 'http://schemas.xmlsoap.org/wsdl/'}]},
#     'name': 'WSDL',
#     'request': ''}]}]

# %%
from lxml import etree

text = '''<feed xmlns="http://www.w3.org/2005/Atom" xmlns:georss="http://www.georss.org/georss"
 xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">
 <title>ScienceBase search results</title>
 <author>
  <name>USGS ScienceBase</name>
  <uri>http://www.sciencebase.gov/</uri>
 </author></feed>
'''

def check_count(context, test, if_true, if_false):
    print test, type(test)
    return if_true if test else if_false
ns = etree.FunctionNamespace(None)
ns['check_count'] = check_count


xml = etree.fromstring(text)

# xml.xpath('/*[@* = "http://a9.com/-/spec/opensearch/1.1/"]')

# xml.xpath("count(/*/namespace::*[. = 'http://a9.com/-/spec/opensearch/1.1/']) = count(/*/namespace::*)")

xml.xpath('check_count(count(/*/namespace::*[. = "http://a9.com/-/spec/opensearch/1.1/"]) = count(/*/namespace::*), 0, 1)')
# Out:
# False <type 'bool'>
# 1.0
